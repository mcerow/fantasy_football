# %% [markdown]
# # Week 11 -- Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %% [markdown]
# ## Functions

# %%
def check_names(df1, df2):
    """
    This funciton compares the list of names from one dataframe to another and updates where the names do not match 
    so they will merge correctly.
    
    Parameters:
        df1: first dataframe to compare to; this should be the dataframe on the left that you will join with when 
        they merge.
        df2: second dataframe, should be the dataframe on the right for the later merge.
        
    Returns:
        Updated name list for df2 that should match df1.
    """
    
    df_players = list(df1['Player'])    
    for i in range(len(df2['Player'])):
        name = df2['Player'][i]
        split_name = name.split(' ')
        if (split_name[0] + ' ' + split_name[1]) in df_players:
            df2['Player'][i] = split_name[0] + ' ' + split_name[1]
        else:
            df2['Player'][i] = name

# %%
def name_update(dataframe, column):
    """
    This function updates a column in a dataframe by stripping any excess spaces surrounding the observation.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column: the column you want to update.
    
    Returns:
        Updated dataframe column.    
    """
    dataframe[column] = dataframe[column].map(lambda x: x.strip())

# %%
def update_int_dtype(dataframe, column_list):
    """
    This function updates the data type for a list of columns to integer.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe column data types to integer.   
    """
    for column in column_list:
        dataframe[column] = dataframe[column].map(lambda x: int(x))

# %%
def update_float_dtype(dataframe, column_list):
    """
    This function takes a dataframe object and converts it to a float.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
    
    Returns:
        Updated dataframe column data types to a float.  
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = '0.0'
            else:
                dataframe[column][i] = item 
            updated_item = str(dataframe[column][i])
            ones, tenths = updated_item.split('.')
            ones = int(ones)
            tenths = int(tenths) * .1
            dataframe[column][i] = ones + tenths
        dataframe[column] = dataframe[column].map(lambda x: float(x))

# %%
def fill_blanks(dataframe, column_list):
    """
    This function fills blank values with 0. This should be used for a column that will be an integer.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.    
    
    Returns:
        Updated dataframe columns with filled values.      
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = 0
            else:
                dataframe[column][i] = item

# %%
def remove_comma(dataframe, column_list):
    """
    This function removes the comma from a value in a column.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe columns less any commas that might appear.    
    """  
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if len(item.split(',')) > 1:
                one, two = item.split(',')
                dataframe[column][i] = one + two

# %%
def adjust_float(dataframe, column_list):
    """
    This function adjusts values in a column to be workable with the 'update_float_dtype' function.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe columns with objects with a decimal point value behind it.    
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if len(item) < 3:
                dataframe[column][i] = item + '.0'
            else:
                dataframe[column][i] = item

# %%
def update_percent(dataframe, column):
    """
    This function updates a column with a percent sign so it can be manipulated into a float with the 
    'update_float_dtype' function.
    
    Parameters:
       dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe column with no percent sign and added decimal point where needed.     
    """
    dataframe[column] = dataframe[column].map(lambda x: x.strip('%'))
    for i in range(len(dataframe[column])):
        item = dataframe[column][i]
        if len(item) < 3:
            dataframe[column][i] = item + '.0'
        else:
            dataframe[column][i] = item

# %%
def replace_dash(dataframe, column_list, dash):
    """
    This function replaces a - in a dataframe so datatypes can then be updated.
    
    Parameters:
       dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        dash: set to a value in a specific column in the dataframe.
        
    Returns:
        Updated dataframe column with no percent sign and added decimal point where needed. 
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == dash:
                dataframe[column][i] = '0'
            else:
                dataframe[column][i] = item

# %% [markdown]
# ## Read in Collected Data

# %%
df = pd.read_pickle('player_stats')
fantasy_pts = pd.read_pickle('fantasy_weeks')
defense = pd.read_pickle('defense_data')
kicking = pd.read_pickle('kicking_data')

# %% [markdown]
# ## Merge Last Week Fantasy Pts with this Week

# %%
no_games = 10

# %%
lastwk = pd.read_pickle('fantweeks_1_' + str(no_games - 1))
lastwk.head()
# Out:
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  240.4   27.3   33.1   24.7   23.1   27.3
# 1  Patrick Mahomes II   KC       QB  238.9   20.4   27.5   40.0   20.2   30.7
# 2      Russell Wilson  SEA       QB  236.1   31.8   34.4   36.8   21.9   25.5
# 3          Josh Allen  BUF       QB  220.6   28.2   34.5   32.2   25.4   18.3
# 4       Aaron Rodgers   GB       QB  187.6   30.8   18.2   24.5   29.6    NaN
#
#   Week_6 Week_7 Week_8 Week_9
# 0   28.9   38.1    NaN   37.9
# 1   20.6   12.0   36.6   30.9
# 2    NaN   32.9   28.7   24.1
# 3   16.1   16.4   13.5   36.0
# 4    5.8   27.3   22.5   28.9

# %%
fantasy_pts = pd.merge(fantasy_pts, lastwk, 'left', on='Player')
fantasy_pts.head()
# Out:
#                Player Team_x Position_x  TTL_x Week_10 Team_y Position_y  \
# 0        Kyler Murray    ARI         QB  271.3    30.9    ARI         QB
# 1          Josh Allen    BUF         QB  249.0    28.4    BUF         QB
# 2      Russell Wilson    SEA         QB  248.0    11.9    SEA         QB
# 3  Patrick Mahomes II     KC         QB  239.5     NaN     KC         QB
# 4       Aaron Rodgers     GB         QB  214.0    26.4     GB         QB
#
#    TTL_y Week_1 Week_2 Week_3 Week_4 Week_5 Week_6 Week_7 Week_8 Week_9
# 0  240.4   27.3   33.1   24.7   23.1   27.3   28.9   38.1    NaN   37.9
# 1  220.6   28.2   34.5   32.2   25.4   18.3   16.1   16.4   13.5   36.0
# 2  236.1   31.8   34.4   36.8   21.9   25.5    NaN   32.9   28.7   24.1
# 3  238.9   20.4   27.5   40.0   20.2   30.7   20.6   12.0   36.6   30.9
# 4  187.6   30.8   18.2   24.5   29.6    NaN    5.8   27.3   22.5   28.9

# %%
fantasy_pts.drop(columns=['Team_y', 'Position_y', 'TTL_y'], inplace=True)
fantasy_pts.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position', 'TTL_x': 'TTL'}, inplace = True)
fantasy_pts.columns
# Out:
# Index(['Player', 'Team', 'Position', 'TTL', 'Week_10', 'Week_1', 'Week_2',
#        'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9'],
#       dtype='object')

# %%
fantasy_pts = fantasy_pts[['Player', 'Team', 'Position', 'TTL', 'Week_1', 'Week_2', 'Week_3', 'Week_4', 'Week_5', 
                           'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10']]
fantasy_pts.head()
# Out:
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  271.3   27.3   33.1   24.7   23.1   27.3
# 1          Josh Allen  BUF       QB  249.0   28.2   34.5   32.2   25.4   18.3
# 2      Russell Wilson  SEA       QB  248.0   31.8   34.4   36.8   21.9   25.5
# 3  Patrick Mahomes II   KC       QB  239.5   20.4   27.5   40.0   20.2   30.7
# 4       Aaron Rodgers   GB       QB  214.0   30.8   18.2   24.5   29.6    NaN
#
#   Week_6 Week_7 Week_8 Week_9 Week_10
# 0   28.9   38.1    NaN   37.9    30.9
# 1   16.1   16.4   13.5   36.0    28.4
# 2    NaN   32.9   28.7   24.1    11.9
# 3   20.6   12.0   36.6   30.9     NaN
# 4    5.8   27.3   22.5   28.9    26.4

# %%
print(fantasy_pts.shape)
# Out:
# (658, 14)

# %% [markdown]
# ### Pickle Combined DataFrame for Next Week

# %%
fantasy_pts.to_pickle('fantweeks_1_' + str(no_games))

# %% [markdown]
# ## Merge Offensive Players & Weekly Fantasy Pts

# %%
print(df.shape)
df.head()
# Out:
# (569, 28)
#           Player Team Position Age Games GamesStarted CompletedPasses  \
# 0    Dalvin Cook  MIN       RB  25     8            8               0
# 1   Alvin Kamara  NOR       RB  25     9            6               0
# 2   Kyler Murray  ARI       QB  23     9            9             212
# 3  Derrick Henry  TEN       RB  26     9            9               0
# 4     Josh Allen  BUF       QB  24    10           10             249
#
#   PassesAttempted PassingYds PassingTDs Interceptions RushingAttempts  \
# 0               0          0          0             0             174
# 1               0          0          0             0             104
# 2             311       2375         17             8              87
# 3               0          0          0             0             201
# 4             364       2871         21             7              72
#
#   RushingYds RushingYdspAtt RushingTDs Targeted Receptions ReceivingYds  \
# 0        954           5.48         12       25         20          189
# 1        486           4.67          7       80         67          648
# 2        604           6.94         10        0          0            0
# 3        946           4.71          8       20         11           87
# 4        279           3.88          5        1          1           12
#
#   YdspReception ReceivingTDs Fumbles LostFumbles TtlTDs TwoPTConversions  \
# 0          9.45            1       2           1     13                3
# 1          9.67            4       1           0     11
# 2                          0       4           2     10
# 3          7.91            0       0           0      8
# 4         12.00            1       4           4      6
#
#   TwoPTConversionPasses FDFantasyPts PositionRank OverallRank
# 0                              206.3            1           1
# 1                              212.9            2           2
# 2                              271.4            1           3
# 3                              156.8            3           4
# 4                              249.4            2           5

# %%
print(fantasy_pts.shape)
fantasy_pts.head()
# Out:
# (658, 14)
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  271.3   27.3   33.1   24.7   23.1   27.3
# 1          Josh Allen  BUF       QB  249.0   28.2   34.5   32.2   25.4   18.3
# 2      Russell Wilson  SEA       QB  248.0   31.8   34.4   36.8   21.9   25.5
# 3  Patrick Mahomes II   KC       QB  239.5   20.4   27.5   40.0   20.2   30.7
# 4       Aaron Rodgers   GB       QB  214.0   30.8   18.2   24.5   29.6    NaN
#
#   Week_6 Week_7 Week_8 Week_9 Week_10
# 0   28.9   38.1    NaN   37.9    30.9
# 1   16.1   16.4   13.5   36.0    28.4
# 2    NaN   32.9   28.7   24.1    11.9
# 3   20.6   12.0   36.6   30.9     NaN
# 4    5.8   27.3   22.5   28.9    26.4

# %%
check_names(df, fantasy_pts)

# %%
name_update(df, 'Player')
name_update(fantasy_pts, 'Player')

# %%
offense = pd.merge(df, fantasy_pts, 'left', on='Player')

# %%
offense.drop(columns = ['Team_y', 'Position_y'], inplace = True)
offense.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position'}, inplace = True)

# %%
print(offense.shape)
offense.head(10)
# Out:
# (569, 39)
#             Player Team Position Age Games GamesStarted CompletedPasses  \
# 0      Dalvin Cook  MIN       RB  25     8            8               0
# 1     Alvin Kamara  NOR       RB  25     9            6               0
# 2     Kyler Murray  ARI       QB  23     9            9             212
# 3    Derrick Henry  TEN       RB  26     9            9               0
# 4       Josh Allen  BUF       QB  24    10           10             249
# 5  Patrick Mahomes  KAN       QB  25     9            9             220
# 6   Russell Wilson  SEA       QB  32     9            9             233
# 7     Travis Kelce  KAN       TE  31     9            9               0
# 8      Tyreek Hill  KAN       WR  26     9            9               0
# 9     D.K. Metcalf  SEA       WR  23     9            9               0
#
#   PassesAttempted PassingYds PassingTDs Interceptions RushingAttempts  \
# 0               0          0          0             0             174
# 1               0          0          0             0             104
# 2             311       2375         17             8              87
# 3               0          0          0             0             201
# 4             364       2871         21             7              72
# 5             329       2687         25             1              35
# 6             334       2789         28            10              45
# 7               0          0          0             0               0
# 8               0          0          0             0               8
# 9               0          0          0             0               0
#
#   RushingYds RushingYdspAtt RushingTDs Targeted Receptions ReceivingYds  \
# 0        954           5.48         12       25         20          189
# 1        486           4.67          7       80         67          648
# 2        604           6.94         10        0          0            0
# 3        946           4.71          8       20         11           87
# 4        279           3.88          5        1          1           12
# 5        171           4.89          2        0          0            0
# 6        325           7.22          1        0          0            0
# 7          0                         0       80         58          769
# 8         62           7.75          1       72         44          650
# 9          0                         0       72         45          816
#
#   YdspReception ReceivingTDs Fumbles LostFumbles TtlTDs TwoPTConversions  \
# 0          9.45            1       2           1     13                3
# 1          9.67            4       1           0     11
# 2                          0       4           2     10
# 3          7.91            0       0           0      8
# 4         12.00            1       4           4      6
# 5                          0       1           0      2
# 6                          0       4           3      1
# 7         13.26            6       1           1      6
# 8         14.77            9       1           0     10
# 9         18.13            8       1           1      8
#
#   TwoPTConversionPasses FDFantasyPts PositionRank OverallRank    TTL Week_1  \
# 0                              206.3            1           1  196.3   20.8
# 1                              212.9            2           2  179.4   18.7
# 2                              271.4            1           3  271.3   27.3
# 3                              156.8            3           4  151.3   13.1
# 4                              249.4            2           5  249.0   28.2
# 5                     2        239.6            3           6  239.5   20.4
# 6                     1        248.1            4           7  248.0   31.8
# 7                              139.9            1           8  110.9   11.0
# 8                              153.2            1           9  131.2   10.6
# 9                              150.1            2          10  127.6   15.5
#
#   Week_2 Week_3 Week_4 Week_5 Week_6 Week_7 Week_8 Week_9 Week_10
# 0   15.1   23.9   26.6   14.9    NaN    NaN   46.6   37.2    11.2
# 1   29.4   31.7   17.9   11.9    NaN   14.8   16.3   10.9    27.8
# 2   33.1   24.7   23.1   27.3   28.9   38.1    NaN   37.9    30.9
# 3    8.4   25.0    NaN   18.3   38.4   13.2   17.2    6.8    10.9
# 4   34.5   32.2   25.4   18.3   16.1   16.4   13.5   36.0    28.4
# 5   27.5   40.0   20.2   30.7   20.6   12.0   36.6   30.9     NaN
# 6   34.4   36.8   21.9   25.5    NaN   32.9   28.7   24.1    11.9
# 7   15.0    8.7    7.0   16.8   16.5    3.1   16.9   15.9     NaN
# 8   16.8   16.2   12.4   15.3    2.5   11.5   21.8   24.1     NaN
# 9   15.2   15.0   10.6   21.3    NaN    2.3   28.1   16.8     2.8

# %%
offense.isnull().sum()
# Out:
# Player                     0
# Team                       0
# Position                   0
# Age                        0
# Games                      0
# GamesStarted               0
# CompletedPasses            0
# PassesAttempted            0
# PassingYds                 0
# PassingTDs                 0
# Interceptions              0
# RushingAttempts            0
# RushingYds                 0
# RushingYdspAtt             0
# RushingTDs                 0
# Targeted                   0
# Receptions                 0
# ReceivingYds               0
# YdspReception              0
# ReceivingTDs               0
# Fumbles                    0
# LostFumbles                0
# TtlTDs                     0
# TwoPTConversions           0
# TwoPTConversionPasses      0
# FDFantasyPts               0
# PositionRank               0
# OverallRank                0
# TTL                       22
# Week_1                   162
# Week_2                   164
# Week_3                   165
# Week_4                   191
# Week_5                   221
# Week_6                   217
# Week_7                   220
# Week_8                   265
# Week_9                   271
# Week_10                  272
# dtype: int64

# %%
offense.fillna('0.0', inplace = True)

# %%
off_integers = ['Age', 'Games', 'GamesStarted', 'CompletedPasses', 'PassesAttempted', 'PassingYds', 'PassingTDs', 
            'Interceptions', 'RushingAttempts', 'RushingYds', 'RushingTDs', 'Targeted', 'Receptions', 
            'ReceivingYds', 'ReceivingTDs', 'Fumbles', 'LostFumbles', 'TtlTDs']

off_floats = ['RushingYdspAtt', 'YdspReception', 'FDFantasyPts', 'TTL','Week_1', 'Week_2', 'Week_3', 'Week_4', 
              'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10']

# %%
update_int_dtype(offense, off_integers)

# %%
two_pts = ['TwoPTConversions', 'TwoPTConversionPasses']
fill_blanks(offense, two_pts)
update_int_dtype(offense, two_pts)

# %%
update_float_dtype(offense, off_floats)

# %%
offense.head()
# Out:
#           Player Team Position  Age  Games  GamesStarted  CompletedPasses  \
# 0    Dalvin Cook  MIN       RB   25      8             8                0
# 1   Alvin Kamara  NOR       RB   25      9             6                0
# 2   Kyler Murray  ARI       QB   23      9             9              212
# 3  Derrick Henry  TEN       RB   26      9             9                0
# 4     Josh Allen  BUF       QB   24     10            10              249
#
#    PassesAttempted  PassingYds  PassingTDs  Interceptions  RushingAttempts  \
# 0                0           0           0              0              174
# 1                0           0           0              0              104
# 2              311        2375          17              8               87
# 3                0           0           0              0              201
# 4              364        2871          21              7               72
#
#    RushingYds  RushingYdspAtt  RushingTDs  Targeted  Receptions  ReceivingYds  \
# 0         954             9.8          12        25          20           189
# 1         486            10.7           7        80          67           648
# 2         604            15.4          10         0           0             0
# 3         946            11.1           8        20          11            87
# 4         279            11.8           5         1           1            12
#
#    YdspReception  ReceivingTDs  Fumbles  LostFumbles  TtlTDs  \
# 0           13.5             1        2            1      13
# 1           15.7             4        1            0      11
# 2            0.0             0        4            2      10
# 3           16.1             0        0            0       8
# 4           12.0             1        4            4       6
#
#    TwoPTConversions  TwoPTConversionPasses  FDFantasyPts PositionRank  \
# 0                 3                      0         206.3            1
# 1                 0                      0         212.9            2
# 2                 0                      0         271.4            1
# 3                 0                      0         156.8            3
# 4                 0                      0         249.4            2
#
#   OverallRank   TTL  Week_1  Week_2  Week_3  Week_4  Week_5  Week_6  Week_7  \
# 0           1 196.3    20.8    15.1    23.9    26.6    14.9     0.0     0.0
# 1           2 179.4    18.7    29.4    31.7    17.9    11.9     0.0    14.8
# 2           3 271.3    27.3    33.1    24.7    23.1    27.3    28.9    38.1
# 3           4 151.3    13.1     8.4    25.0     0.0    18.3    38.4    13.2
# 4           5 249.0    28.2    34.5    32.2    25.4    18.3    16.1    16.4
#
#    Week_8  Week_9  Week_10
# 0    46.6    37.2     11.2
# 1    16.3    10.9     27.8
# 2     0.0    37.9     30.9
# 3    17.2     6.8     10.9
# 4    13.5    36.0     28.4

# %%
team_dict = {'LAR': 'Los Angeles Rams', 
             'SEA': 'Seattle Seahawks', 
             'BAL': 'Baltimore Ravens', 
             'KAN': 'Kansas City Chiefs', 
             'JAX': 'Jacksonville Jaguars', 
             'DET': 'Detroit Lions', 
             'PIT': 'Pittsburgh Steelers', 
             'MIN': 'Minnesota Vikings', 
             'CHI': 'Chicago Bears', 
             'ATL': 'Atlanta Falcons', 
             'BUF': 'Buffalo Bills', 
             'GNB': 'Green Bay Packers', 
             'MIA': 'Miami Dolphins', 
             'CLE': 'Cleveland Browns', 
             'CAR': 'Carolina Panthers', 
             'DAL': 'Dallas Cowboys', 
             'ARI': 'Arizona Cardinals', 
             'HOU': 'Houston Texans', 
             'NYG': 'New York Giants', 
             'WAS': 'Washington Football Team', 
             'IND': 'Indianapolis Colts', 
             'LVR': 'Las Vegas Raiders', 
             'DEN': 'Denver Broncos', 
             'TEN': 'Tennessee Titans', 
             'NWE': 'New England Patriots', 
             'CIN': 'Cincinnati Bengals', 
             'NYJ': 'New York Jets', 
             'LAC': 'Los Angeles Chargers', 
             'PHI': 'Philadelphia Eagles', 
             'TAM': 'Tampa Bay Buccaneers', 
             'NOR': 'New Orleans Saints', 
             'SFO': 'San Francisco 49ers'}

team_names = pd.DataFrame()
team_names['Team'] = list(team_dict.keys())
team_names['Long_Name'] = list(team_dict.values())
team_names.head()
# Out:
#   Team             Long_Name
# 0  LAR      Los Angeles Rams
# 1  SEA      Seattle Seahawks
# 2  BAL      Baltimore Ravens
# 3  KAN    Kansas City Chiefs
# 4  JAX  Jacksonville Jaguars

# %%
offense.dtypes
# Out:
# Player                    object
# Team                      object
# Position                  object
# Age                        int64
# Games                      int64
# GamesStarted               int64
# CompletedPasses            int64
# PassesAttempted            int64
# PassingYds                 int64
# PassingTDs                 int64
# Interceptions              int64
# RushingAttempts            int64
# RushingYds                 int64
# RushingYdspAtt           float64
# RushingTDs                 int64
# Targeted                   int64
# Receptions                 int64
# ReceivingYds               int64
# YdspReception            float64
# ReceivingTDs               int64
# Fumbles                    int64
# LostFumbles                int64
# TtlTDs                     int64
# TwoPTConversions           int64
# TwoPTConversionPasses      int64
# FDFantasyPts             float64
# PositionRank              object
# OverallRank               object
# TTL                      float64
# Week_1                   float64
# Week_2                   float64
# Week_3                   float64
# Week_4                   float64
# Week_5                   float64
# Week_6                   float64
# Week_7                   float64
# Week_8                   float64
# Week_9                   float64
# Week_10                  float64
# dtype: object

# %% [markdown]
# ## Defense Stats

# %%
defense.head()
# Out:
#                   Team GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0     Baltimore Ravens  9             165                       570
# 1     Los Angeles Rams  9             168                       558
# 2  Pittsburgh Steelers  9             171                       565
# 3   Indianapolis Colts  9             177                       541
# 4       Miami Dolphins  9             182                       594
#
#   Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 0        5.1   2,907         219         987              41.5           7
# 1        4.7   2,668         214         871              36.1           7
# 2        5.1   2,863         221         961                37           5
# 3        4.8   2,614         234         826              30.9           7
# 4        5.8   3,347         244       1,153              42.9          11
#
#   Passing_Att Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds  \
# 0         326               5.9         169                9       1,920
# 1         313               5.6         193              8.7       1,797
# 2         308               6.3         145             11.2       1,902
# 3         286               6.2         142              9.8       1,788
# 4         328                 7         168             10.5       2,194
#
#   Passing_TDs RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles  \
# 0          12     21    16      70.4%            14             4      10
# 1           9     26    15      61.1%            13             8       5
# 2          15     24    14      63.1%            17            11       6
# 3          11     25    16      64.9%            13            11       2
# 4          13     28    20      69.6%            15             8       7
#
#   Sacks
# 0    25
# 1    31
# 2    36
# 3    21
# 4    22

# %%
def_fantasy = fantasy_pts[fantasy_pts['Position'] == 'DST']

# %%
defense_df = pd.merge(defense, def_fantasy, 'left', left_on = 'Team', right_on = 'Player')

# %%
defense_df.head()
# Out:
#                 Team_x GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0     Baltimore Ravens  9             165                       570
# 1     Los Angeles Rams  9             168                       558
# 2  Pittsburgh Steelers  9             171                       565
# 3   Indianapolis Colts  9             177                       541
# 4       Miami Dolphins  9             182                       594
#
#   Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 0        5.1   2,907         219         987              41.5           7
# 1        4.7   2,668         214         871              36.1           7
# 2        5.1   2,863         221         961                37           5
# 3        4.8   2,614         234         826              30.9           7
# 4        5.8   3,347         244       1,153              42.9          11
#
#   Passing_Att Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds  \
# 0         326               5.9         169                9       1,920
# 1         313               5.6         193              8.7       1,797
# 2         308               6.3         145             11.2       1,902
# 3         286               6.2         142              9.8       1,788
# 4         328                 7         168             10.5       2,194
#
#   Passing_TDs RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles  \
# 0          12     21    16      70.4%            14             4      10
# 1           9     26    15      61.1%            13             8       5
# 2          15     24    14      63.1%            17            11       6
# 3          11     25    16      64.9%            13            11       2
# 4          13     28    20      69.6%            15             8       7
#
#   Sacks               Player Team_y Position   TTL Week_1 Week_2 Week_3  \
# 0    25     Baltimore Ravens    BAL      DST  95.0   15.0   15.0    1.0
# 1    31     Los Angeles Rams    LAR      DST  71.0    4.0    7.0    4.0
# 2    36  Pittsburgh Steelers    PIT      DST  93.0    8.0   13.0    7.0
# 3    21   Indianapolis Colts    IND      DST  98.0    4.0   15.0   26.0
# 4    22       Miami Dolphins    MIA      DST  81.0    2.0    2.0   12.0
#
#   Week_4 Week_5 Week_6 Week_7 Week_8 Week_9 Week_10
# 0    6.0   26.0    7.0    NaN    4.0   14.0     1.0
# 1   11.0   12.0    0.0   15.0    5.0    NaN    13.0
# 2   10.0    8.0   18.0    2.0   18.0    7.0    12.0
# 3    7.0    5.0    4.0    NaN   15.0    5.0    10.0
# 4    3.0   12.0   15.0    NaN   17.0    8.0     4.0

# %%
defense_df.drop(columns=['Player', 'Team_y', 'Position'], inplace=True)
defense_df.rename(columns={'Team_x': 'Team'}, inplace=True)

# %%
defense_df.head()
# Out:
#                   Team GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0     Baltimore Ravens  9             165                       570
# 1     Los Angeles Rams  9             168                       558
# 2  Pittsburgh Steelers  9             171                       565
# 3   Indianapolis Colts  9             177                       541
# 4       Miami Dolphins  9             182                       594
#
#   Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 0        5.1   2,907         219         987              41.5           7
# 1        4.7   2,668         214         871              36.1           7
# 2        5.1   2,863         221         961                37           5
# 3        4.8   2,614         234         826              30.9           7
# 4        5.8   3,347         244       1,153              42.9          11
#
#   Passing_Att Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds  \
# 0         326               5.9         169                9       1,920
# 1         313               5.6         193              8.7       1,797
# 2         308               6.3         145             11.2       1,902
# 3         286               6.2         142              9.8       1,788
# 4         328                 7         168             10.5       2,194
#
#   Passing_TDs RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles  \
# 0          12     21    16      70.4%            14             4      10
# 1           9     26    15      61.1%            13             8       5
# 2          15     24    14      63.1%            17            11       6
# 3          11     25    16      64.9%            13            11       2
# 4          13     28    20      69.6%            15             8       7
#
#   Sacks   TTL Week_1 Week_2 Week_3 Week_4 Week_5 Week_6 Week_7 Week_8 Week_9  \
# 0    25  95.0   15.0   15.0    1.0    6.0   26.0    7.0    NaN    4.0   14.0
# 1    31  71.0    4.0    7.0    4.0   11.0   12.0    0.0   15.0    5.0    NaN
# 2    36  93.0    8.0   13.0    7.0   10.0    8.0   18.0    2.0   18.0    7.0
# 3    21  98.0    4.0   15.0   26.0    7.0    5.0    4.0    NaN   15.0    5.0
# 4    22  81.0    2.0    2.0   12.0    3.0   12.0   15.0    NaN   17.0    8.0
#
#   Week_10
# 0     1.0
# 1    13.0
# 2    12.0
# 3    10.0
# 4     4.0

# %%
defense_df.isnull().sum()
# Out:
# Team                         0
# GP                           0
# Ttl_Pts_Allowed              0
# Ttl_Offense_Plays_Allowed    0
# Yds_p_Play                   0
# Ttl_Yds                      0
# Rushing_Att                  0
# Rushing_Yds                  0
# Rushing_Yds_p_Att            0
# Rushing_TDs                  0
# Passing_Att                  0
# Passing_Yds_p_Att            0
# Completions                  0
# Yds_p_Completion             0
# Passing_Yds                  0
# Passing_TDs                  0
# RZ_Att                       0
# RZ_TD                        0
# RZ_Percent                   0
# Ttl_Turnovers                0
# Interceptions                0
# Fumbles                      0
# Sacks                        0
# TTL                          0
# Week_1                       0
# Week_2                       0
# Week_3                       0
# Week_4                       0
# Week_5                       4
# Week_6                       4
# Week_7                       4
# Week_8                       4
# Week_9                       4
# Week_10                      4
# dtype: int64

# %%
defense_df
# Out:
#                         Team  GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0           Baltimore Ravens   9             165                       570
# 1           Los Angeles Rams   9             168                       558
# 2        Pittsburgh Steelers   9             171                       565
# 3         Indianapolis Colts   9             177                       541
# 4             Miami Dolphins   9             182                       594
# 5         Kansas City Chiefs   9             183                       589
# 6              Chicago Bears  10             209                       658
# 7          Arizona Cardinals   9             210                       609
# 8       New England Patriots   9             211                       520
# 9         New Orleans Saints   9             213                       549
# 10  Washington Football Team   9             218                       553
# 11         Green Bay Packers   9             224                       523
# 12      Tampa Bay Buccaneers  10             226                       618
# 13       Philadelphia Eagles   9             232                       612
# 14       San Francisco 49ers  10             234                       603
# 15          Tennessee Titans   9             235                       618
# 16           New York Giants  10             236                       642
# 17          Cleveland Browns   9             244                       599
# 18      Los Angeles Chargers   9             245                       561
# 19         Minnesota Vikings   9             247                       599
# 20        Cincinnati Bengals   9             250                       577
# 21           Atlanta Falcons   9             251                       572
# 22            Houston Texans   9             252                       606
# 23         Las Vegas Raiders   9             254                       657
# 24            Denver Broncos   9             254                       614
# 25             Buffalo Bills  10             265                       640
# 26          Seattle Seahawks   9             266                       658
# 27             Detroit Lions   9             267                       607
# 28             New York Jets   9             268                       598
# 29      Jacksonville Jaguars   9             271                       583
# 30         Carolina Panthers  10             272                       644
# 31            Dallas Cowboys   9             290                       596
#
#    Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 
# 23     9  34.0    0.0    2.0    3.0    0.0    4.0    NaN   -4.0    9.0    4.0
# 24    22  34.0    2.0    5.0    1.0    6.0    NaN   14.0    2.0    5.0    3.0
# 25    27  56.0    8.0    2.0    5.0    6.0   -4.0    3.0   14.0    4.0   12.0
# 26    22  45.0    6.0    3.0    9.0    5.0    7.0    NaN    0.0    7.0    3.0
# 27    13  17.0    1.0   -3.0    7.0    0.0    NaN    6.0    4.0   -2.0    0.0
# 28    11  27.0    7.0    4.0    0.0    8.0    2.0    6.0    5.0   -4.0   -1.0
# 29     9  37.0    6.0    0.0    0.0    2.0    4.0    1.0    9.0    NaN    4.0
# 30    10  32.0   -1.0    3.0   11.0    3.0    5.0    2.0    3.0    4.0    2.0
# 31    17  20.0    4.0   -3.0    0.0   -2.0    9.0   -3.0    2.0   13.0    0.0
#
#    Week_10
# 0      1.0
# 1     13.0
# 2     12.0
# 3     10.0
# 4      4.0
# 5      NaN
# 6     12.0
# 7      3.0
# 8      5.0
# 9     14.0
# 10     0.0
# 11     6.0
# 12     5.0
# 13     3.0
# 14     7.0
# 15     1.0
# 16     4.0
# 17     6.0
# 18     1.0
# 19    10.0
# 20    -4.0
# 21     NaN
# 22     5.0
# 23    16.0
# 24    -4.0
# 25     6.0
# 26     5.0
# 27     4.0
# 28     NaN
# 29    11.0
# 30    -1.0
# 31     NaN

# %%
defense_df.fillna('0.0', inplace=True)

# %%
def_int = ['GP', 'Ttl_Pts_Allowed', 'Ttl_Offense_Plays_Allowed', 'Ttl_Yds', 'Rushing_Att', 'Rushing_Yds', 
           'Rushing_TDs', 'Passing_Att', 'Completions', 'Passing_Yds', 'Passing_TDs', 'RZ_Att', 'RZ_TD', 
           'Ttl_Turnovers', 'Interceptions', 'Fumbles', 'Sacks']

def_floats = ['Yds_p_Play', 'TTL', 'Week_1', 
              'Week_2', 'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10']

# 'Rushing_Yds_p_Att', 'Passing_Yds_p_Att', 'Yds_p_Completion',

# %%
remove_comma(defense_df, def_int)

# %%
update_int_dtype(defense_df, def_int)

# %%
adjust_float(defense_df, def_floats)

# %%
defense_df['Rushing_Yds_p_Att'] = round(defense_df['Rushing_Yds']/defense_df['Rushing_Att'], 2)
defense_df['Passing_Yds_p_Att'] = round(defense_df['Passing_Yds']/defense_df['Passing_Att'], 2)
defense_df['Yds_p_Completion'] = round(defense_df['Passing_Yds']/defense_df['Completions'], 2)

# %%
update_float_dtype(defense_df, def_floats)

# %%
update_percent(defense_df, 'RZ_Percent')

# %%
rz = ['RZ_Percent']
update_float_dtype(defense_df, rz)

# %%
defense_df.head()
# Out:
#                   Team  GP  Ttl_Pts_Allowed  Ttl_Offense_Plays_Allowed  \
# 0     Baltimore Ravens   9              165                        570
# 1     Los Angeles Rams   9              168                        558
# 2  Pittsburgh Steelers   9              171                        565
# 3   Indianapolis Colts   9              177                        541
# 4       Miami Dolphins   9              182                        594
#
#    Yds_p_Play  Ttl_Yds  Rushing_Att  Rushing_Yds  Rushing_Yds_p_Att  \
# 0         5.1     2907          219          987                4.5
# 1         4.7     2668          214          871                4.1
# 2         5.1     2863          221          961                4.3
# 3         4.8     2614          234          826                3.5
# 4         5.8     3347          244         1153                4.7
#
#    Rushing_TDs  Passing_Att  Passing_Yds_p_Att  Completions  Yds_p_Completion  \
# 0            7          326                5.9          169              11.4
# 1            7          313                5.7          193               9.3
# 2            5          308                6.2          145              13.1
# 3            7          286                6.2          142              12.6
# 4           11          328                6.7          168              13.1
#
#    Passing_Yds  Passing_TDs  RZ_Att  RZ_TD  RZ_Percent  Ttl_Turnovers  \
# 0         1920           12      21     16        70.4             14
# 1         1797            9      26     15        61.1             13
# 2         1902           15      24     14        63.1             17
# 3         1788           11      25     16        64.9             13
# 4         2194           13      28     20        69.6             15
#
#    Interceptions  Fumbles  Sacks  TTL  Week_1  Week_2  Week_3  Week_4  Week_5  \
# 0              4       10     25 95.0    15.0    15.0     1.0     6.0    26.0
# 1              8        5     31 71.0     4.0     7.0     4.0    11.0    12.0
# 2             11        6     36 93.0     8.0    13.0     7.0    10.0     8.0
# 3             11        2     21 98.0     4.0    15.0    26.0     7.0     5.0
# 4              8        7     22 81.0     2.0     2.0    12.0     3.0    12.0
#
#    Week_6  Week_7  Week_8  Week_9  Week_10
# 0     7.0     0.0     4.0    14.0      1.0
# 1     0.0    15.0     5.0     0.0     13.0
# 2    18.0     2.0    18.0     7.0     12.0
# 3     4.0     0.0    15.0     5.0     10.0
# 4    15.0     0.0    17.0     8.0      4.0

# %%
defense_df.dtypes
# Out:
# Team                          object
# GP                             int64
# Ttl_Pts_Allowed                int64
# Ttl_Offense_Plays_Allowed      int64
# Yds_p_Play                   float64
# Ttl_Yds                        int64
# Rushing_Att                    int64
# Rushing_Yds                    int64
# Rushing_Yds_p_Att            float64
# Rushing_TDs                    int64
# Passing_Att                    int64
# Passing_Yds_p_Att            float64
# Completions                    int64
# Yds_p_Completion             float64
# Passing_Yds                    int64
# Passing_TDs                    int64
# RZ_Att                         int64
# RZ_TD                          int64
# RZ_Percent                   float64
# Ttl_Turnovers                  int64
# Interceptions                  int64
# Fumbles                        int64
# Sacks                          int64
# TTL                          float64
# Week_1                       float64
# Week_2                       float64
# Week_3                       float64
# Week_4                       float64
# Week_5                       float64
# Week_6                       float64
# Week_7                       float64
# Week_8                       float64
# Week_9                       float64
# Week_10                      float64
# dtype: object

# %% [markdown]
# ## Kicking Stats

# %%
kicking.head()
# Out:
#            PLAYER POSITION TEAM  GP FGM_A   FG% LNG _1_19 _20_29 _30_39  \
# 0     Ryan Succop        K   TB  10    22  90.9  50   0-0    6-6    7-7
# 1  Daniel Carlson        K   LV   9    22  90.9  54   0-0    9-9    5-5
# 2      Tyler Bass        K  BUF  10    25  76.0  58   1-1    4-4    4-7
# 3        Wil Lutz        K   NO   9    19  94.7  53   0-0    4-5    8-8
# 4   Jason Sanders        K  MIA   9    21  95.2  56   0-0    5-5    3-3
#
#   _40_49 OVER50 XPM_A    XP% PTS
# 0    6-7    1-2    32   93.8  90
# 1    2-4    4-4    28   96.4  87
# 2    6-7    4-6    30   96.7  86
# 3    5-5    1-1    31  100.0  85
# 4    7-8    5-5    23  100.0  83

# %%
kicking_df = pd.merge(kicking, fantasy_pts, left_on = 'PLAYER', right_on = 'Player')
kicking_df.drop(columns = ['Player', 'Team', 'Position'], inplace = True)
kicking_df
# Out:
#                  PLAYER POSITION TEAM  GP FGM_A    FG% LNG _1_19 _20_29  \
# 0           Ryan Succop        K   TB  10    22   90.9  50   0-0    6-6
# 1        Daniel Carlson        K   LV   9    22   90.9  54   0-0    9-9
# 2            Tyler Bass        K  BUF  10    25   76.0  58   1-1    4-4
# 3              Wil Lutz        K   NO   9    19   94.7  53   0-0    4-5
# 4         Jason Sanders        K  MIA   9    21   95.2  56   0-0    5-5
# 5          Younghoe Koo        K  ATL   8    22   95.5  54   0-0    5-5
# 6             Joey Slye        K  CAR  10    25   80.0  48   0-0    8-8
# 7   Rodrigo Blankenship        K  IND   9    21   90.5  44   0-0    5-5
# 8           Graham Gano        K  NYG  10    22   95.5  55   0-0    4-4
# 9         Randy Bullock        K  CIN   9    21   90.5  55   0-0    3-3
# 10        Justin Tucker        K  BAL   9    17   94.1  55   0-0    3-3
# 11          Matt Prater        K  DET   9    23   73.9  59   0-0    3-3
# 12        Zane Gonzalez        K  ARI   9    19   78.9  56   0-0    4-4
# 13      Harrison Butker        K   KC   9    17   88.2  58   1-1    3-3
# 14      Brandon McManus        K  DEN   9    19   94.7  56   0-0    3-3
# 15        Chris Boswell        K  PIT   9    14  100.0  59   0-0    2-2
# 16         Cairo Santos        K  CHI  10    19   89.5  55   0-0    5-5
# 17         Mason Crosby        K   GB   9    12  100.0  53   1-1    0-0
# 18        Greg Zuerlein        K  DAL   9    20   85.0  59   0-0    1-1
# 19         Robbie Gould        K   SF  10    14   92.9  52   0-0    3-3
# 20          Jason Myers        K  SEA   9    10  100.0  61   0-0    0-0
# 21     Ka'imi Fairbairn        K  HOU   9    17   82.4  54   0-0    3-3
# 22            Nick Folk        K   NE   9    17   88.2  51   0-0    4-4
# 23   Stephen Gostkowski        K  TEN   9    20   60.0  55   0-0    1-2
# 24          Cody Parkey        K  CLE   8    12   91.7  46   0-0    1-1
# 25       Dustin Hopkins        K  WAS   9    17   70.6  48   0-0    2-2
# 26           Dan Bailey        K  MIN   9    10   80.0  52   0-0    1-1
# 27           Sam Sloman        K  LAR   7    11   72.7  42   0-0    2-3
# 28         Jake Elliott        K  PHI   9    13   69.2  54   0-0    1-2
# 29           Sam Ficken        K  NYJ   6    10   90.0  54   0-0    3-3
# 30           Josh Lambo        K  JAC   4     5  100.0  59   0-0    0-0
# 31      Sergio Castillo        K  NYJ   3     7   85.7  55   0-0    1-1
# 32        Aldrick Rosas        K  JAC   1     5   80.0  50   0-0    1-1
# 33          Kai Forbath        K  LAR   2     3   66.7  23   0-0    2-2
# 33    NaN    NaN    NaN    5.0    NaN     5.0
# 34    NaN    NaN    NaN    NaN    NaN    10.0
# 35    NaN    4.0    NaN    NaN    NaN     NaN
# 36    NaN    NaN    NaN    NaN    NaN     NaN
# 37    2.0    NaN    NaN    NaN    NaN     NaN
# 38    NaN    NaN    NaN    NaN    NaN     NaN
# 39    NaN    NaN    NaN    NaN    NaN     NaN

# %%
dash = kicking_df['LNG'][38]
dash
# Out:
# '—'

# %%
kicking_df.fillna('0.0', inplace = True)

# %%
kick_int = ['GP', 'FGM_A', 'LNG', 'XPM_A', 'PTS']

kick_float = ['FG%', 'XP%', 'TTL', 'Week_1', 'Week_2', 'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 
              'Week_9', 'Week_10']

# %%
replace_dash(kicking_df, kick_int, dash)

# %%
replace_dash(kicking_df, kick_float, dash)

# %%
update_int_dtype(kicking_df, kick_int)

# %%
adjust_float(kicking_df, kick_float)

# %%
update_float_dtype(kicking_df, kick_float)

# %%
kicking_df.head()
# Out:
#            PLAYER POSITION TEAM  GP  FGM_A  FG%  LNG _1_19 _20_29 _30_39  \
# 0     Ryan Succop        K   TB  10     22 90.9   50   0-0    6-6    7-7
# 1  Daniel Carlson        K   LV   9     22 90.9   54   0-0    9-9    5-5
# 2      Tyler Bass        K  BUF  10     25 76.0   58   1-1    4-4    4-7
# 3        Wil Lutz        K   NO   9     19 94.7   53   0-0    4-5    8-8
# 4   Jason Sanders        K  MIA   9     21 95.2   56   0-0    5-5    3-3
#
#   _40_49 OVER50  XPM_A   XP%  PTS   TTL  Week_1  Week_2  Week_3  Week_4  \
# 0    6-7    1-2     32  93.8   90  98.0     5.0     7.0     9.0     8.0
# 1    2-4    4-4     28  96.4   87  97.0    12.0    12.0     8.0    13.0
# 2    6-7    4-6     30  96.7   86 100.0     9.0     7.0     5.0     6.0
# 3    5-5    1-1     31 100.0   85  92.0    10.0     6.0    13.0     5.0
# 4    7-8    5-5     23 100.0   83 100.0     4.0    11.0     7.0    18.0
#
#    Week_5  Week_6  Week_7  Week_8  Week_9  Week_10
# 0    14.0    10.0     9.0    15.0     4.0     17.0
# 1    11.0     0.0     9.0    10.0     7.0     15.0
# 2     5.0     6.0    23.0     6.0    15.0     18.0
# 3    15.0     0.0    11.0    14.0     8.0     10.0
# 4    22.0     6.0     0.0     4.0    14.0     14.0

# %%
kicking_df.dtypes
# Out:
# PLAYER       object
# POSITION     object
# TEAM         object
# GP            int64
# FGM_A         int64
# FG%         float64
# LNG           int64
# _1_19        object
# _20_29       object
# _30_39       object
# _40_49       object
# OVER50       object
# XPM_A         int64
# XP%         float64
# PTS           int64
# TTL         float64
# Week_1      float64
# Week_2      float64
# Week_3      float64
# Week_4      float64
# Week_5      float64
# Week_6      float64
# Week_7      float64
# Week_8      float64
# Week_9      float64
# Week_10     float64
# dtype: object

# %% [markdown]
# ## Pickle Cleaned DataFrames

# %%
offense.to_pickle('players')
team_names.to_pickle('long_names')
defense_df.to_pickle('defense')
kicking_df.to_pickle('kicking')
