# %% [markdown]
# # Week 3 -- Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %% [markdown]
# ## Functions

# %%
def check_names(df1, df2):
    df_players = list(df1['Player'])    
    for i in range(len(df2['Player'])):
        name = df2['Player'][i]
        split_name = name.split(' ')
        if (split_name[0] + ' ' + split_name[1]) in df_players:
            df2['Player'][i] = split_name[0] + ' ' + split_name[1]
        else:
            df2['Player'][i] = name

# %%
def name_update(dateframe):
    dataframe['Player'] = dataframe['Player'].map(lambda x: x.strip())

# %%
def update_int_dtype(dataframe, column_list):
    for column in column_list:
        dataframe[column] = dataframe[column].map(lambda x: int(x))

# %%
def update_float_dtype(dataframe, column_list):
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = '0.0'
            else:
                dataframe[column][i] = item

# %%
def fill_blanks(dataframe, column_list):
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = 0
            else:
                dataframe[column][i] = item

# %%
def remove_comma(dataframe, column_list):
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if len(item.split(',')) > 1:
                one, two = item.split(',')
                dataframe[column][i] = one + two

# %% [markdown]
# ## Read in Collected Data

# %%
df = pd.read_pickle('player_stats')
fantasy_pts = pd.read_pickle('fantasy_weeks')
defense = pd.read_pickle('defense_data')

# %%
defense.head()
# Out:
#                    Team Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed Yds_p_Play  \
# 0      Baltimore Ravens              22                       125        4.9
# 1    Kansas City Chiefs              40                       137        6.1
# 2    Indianapolis Colts              45                       154        4.4
# 3   San Francisco 49ers              46                       189        4.8
# 4  Los Angeles Chargers              57                       188        5.4
#
#   Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs Passing_Att  \
# 0     610          44         189               4.3           0          75
# 1     839          66         301               4.6           3          65
# 2     676          70         280                 4           1          75
# 3     912          80         350               4.4           2         104
# 4   1,011          71         328               4.6           1         111
#
#   Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds Passing_TDs  \
# 0               6.2          46             10.1         464           2
# 1               8.7          42             13.4         564           2
# 2               6.1          47              9.7         454           4
# 3               5.7          64              9.2         588           2
# 4               6.6          72             10.1         730           3
#
#   RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles Sacks
# 0      3     2      66.7%             5             2       3     6
# 1      6     5      83.3%             2             2       0     6
# 2      6     4      66.7%             6             6       0     9
# 3      4     2        50%             4             2       2     5
# 4      9     2      22.2%             2             1       1     6

# %% [markdown]
# ## Merge Last Week Fantasy Pts with this Week

# %%
lastwk = pd.read_pickle('fantweeks_1_2')
lastwk
# Out:
#                        Player Team Position Ttl_Fant Week_1 Week_2
# 0              Russell Wilson  SEA       QB     66.2   31.8   34.4
# 1                  Josh Allen  BUF       QB     62.7   28.2   34.5
# 2                  Cam Newton   NE       QB     61.3   25.7   35.6
# 3                Kyler Murray  ARI       QB     60.4   27.3   33.1
# 4                Dak Prescott  DAL       QB     57.4   17.6   39.8
# 5                 Aaron Jones   GB       RB     55.2   13.6   41.6
# 6                   Matt Ryan  ATL       QB     53.4   24.9   28.5
# 7               Aaron Rodgers   GB       QB     49.0   30.8   18.2
# 8                Alvin Kamara   NO       RB     48.1   18.7   29.4
# 9          Patrick Mahomes II   KC       QB     47.9   20.4   27.5
# 10              Calvin Ridley  ATL       WR     47.8   24.9   22.9
# 11         Gardner Minshew II  JAC       QB     46.3   20.8   25.5
# 60          Leonard Fournette   TB       RB     25.5    1.9   23.6
# 61              Justin Tucker  BAL        K     25.0    9.0   16.0
# 62             Terry McLaurin  WAS       WR     24.6    6.1   18.5
# 63             Dwayne Haskins  WAS       QB     24.5   12.8   11.7
# 64               Kirk Cousins  MIN       QB     24.3   22.8    1.5
# 65                Sam Darnold  NYJ       QB     24.1   12.2   11.9
# 66            Jerick McKinnon   SF       RB     24.1   10.4   13.7
# 67             Daniel Carlson   LV        K     24.0   12.0   12.0
# 68        JuJu Smith-Schuster  PIT       WR     23.7   18.9    4.8
# 69              Austin Ekeler  LAC       RB     23.5    8.7   14.8
# 70              Joshua Kelley  LAC       RB     23.3   12.0   11.3
# 71             Justin Herbert  LAC       QB     23.2    NaN   23.2
# 72               Mason Crosby   GB        K     23.0   12.0   11.0
# 73            Harrison Butker   KC        K     23.0   10.0   13.0
# 74        Rodrigo Blankenship  IND        K     23.0    8.0   15.0
# 75              Randy Bullock  CIN        K     23.0   10.0   13.0
# 76                 Mike Evans   TB       WR     22.6    6.2   16.4
# 77                Keelan Cole  JAC       WR     22.5   10.7   11.8
# 78               Russell Gage  ATL       WR     22.0   11.4   10.6
# 79               Mike Gesicki  MIA       TE     22.0    3.0   19.0
# 80               Kenyan Drake  ARI       RB     22.0   12.5    9.5
# 81   Marquez Valdes-Scantling   GB       WR     22.0   15.6    6.4
# 82              Tyler Lockett  SEA       WR     21.9    9.2   12.7
# 83              David Johnson  HOU       RB     21.9   16.9    5.0
# 84              Derrick Henry  TEN       RB     21.5   13.1    8.4
# 85               Robert Woods  LAR       WR     21.2   11.9    9.3
# 86        Pittsburgh Steelers  PIT      DST     21.0    8.0   13.0
# 87              Zane Gonzalez  ARI        K     21.0    8.0   13.0
# 88              Darren Waller   LV       TE     20.8    4.5   16.3
# 89               Mark Andrews  BAL       TE     20.7   17.8    2.9
# 90               J.K. Dobbins  BAL       RB     20.3   14.2    6.1
# 91            Michael Badgley  LAC        K     20.0   11.0    9.0
# 92               James Conner  PIT       RB     19.8    1.7   18.1
# 93               Jeff Driskel  DEN       QB     19.7    NaN   19.7
# 94               Nyheim Hines  IND       RB     19.7   19.3    0.4
# 95                Corey Davis  TEN       WR     19.7   10.1    9.6
# 96             Chase Claypool  PIT       WR     19.5    4.7   14.8
# 97             Dallas Goedert  PHI       TE     19.1   16.1    3.0
# 98         Indianapolis Colts  IND      DST     19.0    4.0   15.0
# 99         New Orleans Saints   NO      DST     19.0   15.0    4.0
# 100  Washington Football Team  WAS      DST     19.0   15.0    4.0
# 101           Diontae Johnson  PIT       WR     18.9    3.7   15.2
# 102         Darrell Henderson  LAR       RB     18.7    0.6   18.1
# 103              Allen Lazard   GB       WR     18.7   14.2    4.5
# 104               Jordan Reed   SF       TE     18.2    1.2   17.0
# 105              Amari Cooper  DAL       WR     18.1    8.1   10.0
# 106               Julio Jones  ATL       WR     18.1   15.7    2.4
# 107                Josh Lambo  JAC        K     18.0   12.0    6.0
# 108              Robbie Gould   SF        K     18.0   10.0    8.0
# 495             Byron Pringle   KC       WR      0.0    0.0    0.0
# 496            Brandon Powell  ATL       WR      0.0    0.0    0.0
# 497           Christian Blake  ATL       WR      0.0    0.0    0.0
# 498           Trent Sherfield  ARI       WR      0.0    0.0    0.0
# 499                  Cam Sims  WAS       WR      0.0    0.0    0.0
# 500          Jace Sternberger   GB       TE      0.0    0.0    0.0
# 501             Alex Erickson  CIN       WR      0.0    0.0    0.0
# 502             Pharoh Cooper  CAR       WR      0.0    0.0    0.0
# 503             Andre Roberts  BUF       WR      0.0    0.0    0.0
# 504            Kahale Warring  HOU       TE      0.0    0.0    NaN
# 505           Stephen Carlson  CLE       TE      0.0    0.0    0.0
# 506              Devin Asiasi   NE       TE      0.0    0.0    0.0
# 507           Charlie Woerner   SF       TE      0.0    0.0    0.0
# 508              Ben Ellefson  JAC       TE      0.0    0.0    0.0
# 509               Gabe Nabers  LAC       TE      0.0    0.0    0.0
# 510            Matthew Slater   NE       WR      0.0    0.0    0.0
# 511                   Ty Long  LAC        K      0.0    0.0    0.0
# 512              Ted Ginn Jr.  CHI       WR      0.0    0.0    NaN
# 513              Taiwan Jones  BUF       RB      0.0    0.0    0.0
# 514           Jacoby Brissett  IND       QB      0.0    0.0    NaN
# 515         Bennie Fowler III   NO       WR      0.0    0.0    0.0
# 516           Diontae Spencer  DEN       WR      0.0    0.0    0.0
# 517            Austin Seibert  CIN        K      0.0    0.0    NaN
# 518     Nick Westbrook-Ikhine  TEN       WR      0.0    NaN    0.0
# 519           Lynn Bowden Jr.  MIA       RB     -0.1    NaN   -0.1
# 520            John Hightower  PHI       WR     -0.2   -0.2    0.0
# 521                 Tim Boyle   GB       QB     -0.3   -0.2   -0.1
# 522              Nick Vannett  DEN       TE     -0.6   -0.6    0.0
# 523               Keke Coutee  HOU       WR     -0.9    NaN   -0.9
# 524         Minnesota Vikings  MIN      DST     -1.0   -4.0    3.0
# 525             Detroit Lions  DET      DST     -2.0    1.0   -3.0

# %%
fantasy_pts = pd.merge(fantasy_pts, lastwk, 'left', on='Player')
fantasy_pts.head()
# Out:
#                Player Team_x Position_x    TTL Week_3 Team_y Position_y  \
# 0      Russell Wilson    SEA         QB  103.0   36.8    SEA         QB
# 1          Josh Allen    BUF         QB   94.9   32.2    BUF         QB
# 2  Patrick Mahomes II     KC         QB   87.9   40.0     KC         QB
# 3        Dak Prescott    DAL         QB   86.9   29.5    DAL         QB
# 4        Kyler Murray    ARI         QB   85.1   24.7    ARI         QB
#
#   Ttl_Fant Week_1 Week_2
# 0     66.2   31.8   34.4
# 1     62.7   28.2   34.5
# 2     47.9   20.4   27.5
# 3     57.4   17.6   39.8
# 4     60.4   27.3   33.1

# %%
fantasy_pts.drop(columns=['Team_y', 'Position_y', 'Ttl_Fant'], inplace=True)
fantasy_pts.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position'}, inplace = True)
fantasy_pts.columns
# Out:
# Index(['Player', 'Team', 'Position', 'TTL', 'Week_3', 'Week_1', 'Week_2'], dtype='object')

# %%
fantasy_pts = fantasy_pts[['Player', 'Team', 'Position', 'TTL', 'Week_1', 'Week_2', 'Week_3']]
fantasy_pts.head()
# Out:
#                Player Team Position    TTL Week_1 Week_2 Week_3
# 0      Russell Wilson  SEA       QB  103.0   31.8   34.4   36.8
# 1          Josh Allen  BUF       QB   94.9   28.2   34.5   32.2
# 2  Patrick Mahomes II   KC       QB   87.9   20.4   27.5   40.0
# 3        Dak Prescott  DAL       QB   86.9   17.6   39.8   29.5
# 4        Kyler Murray  ARI       QB   85.1   27.3   33.1   24.7

# %%
print(fantasy_pts.shape)
# Out:
# (558, 7)

# %% [markdown]
# ### Pickle Combined DataFrame for Next Week

# %%
fantasy_pts.to_pickle('fantweeks_1_3')

# %% [markdown]
# ## Merge Offensive Players & Weekly Fantasy Pts

# %%
print(df.shape)
df.head()
# Out:
# (461, 28)
#            Player Team Position Age Games GamesStarted CompletedPasses  \
# 0    Alvin Kamara  NOR       RB  25     3            2               0
# 1  Russell Wilson  SEA       QB  32     3            3              79
# 2     Aaron Jones  GNB       RB  26     3            3               0
# 3   Calvin Ridley  ATL       WR  26     3            3               0
# 4      Josh Allen  BUF       QB  24     3            3              81
#
#   PassesAttempted PassingYds PassingTDs Interceptions RushingAttempts  \
# 0               0          0          0             0              31
# 1             103        925         14             1              14
# 2               0          0          0             0              50
# 3               0          0          0             0               2
# 4             114       1038         10             1              22
#
#   RushingYds RushingYdspAtt RushingTDs Targeted Receptions ReceivingYds  \
# 0        153           4.94          3       31         27          285
# 1         90           6.43          0        0          0            0
# 2        303           6.06          4       18         10           95
# 3          6           3.00          0       35         21          349
# 4         84           3.82          2        0          0            0
#
#   YdspReception ReceivingTDs Fumbles LostFumbles TtlTDs TwoPTConversions  \
# 0         10.56            3       0           0      6
# 1                          0       1           0      0
# 2          9.50            1       1           0      5
# 3         16.62            4       0           0      4
# 4                          0       3           3      2
#
#   TwoPTConversionPasses FDFantasyPts PositionRank OverallRank
# 0                               93.3            1           1
# 1                     1        103.0            1           2
# 2                               74.8            2           3
# 3                               70.0            1           4
# 4                               94.9            2           5

# %%
print(fantasy_pts.shape)
fantasy_pts.head()
# Out:
# (558, 7)
#                Player Team Position    TTL Week_1 Week_2 Week_3
# 0      Russell Wilson  SEA       QB  103.0   31.8   34.4   36.8
# 1          Josh Allen  BUF       QB   94.9   28.2   34.5   32.2
# 2  Patrick Mahomes II   KC       QB   87.9   20.4   27.5   40.0
# 3        Dak Prescott  DAL       QB   86.9   17.6   39.8   29.5
# 4        Kyler Murray  ARI       QB   85.1   27.3   33.1   24.7

# %%
check_names(df, fantasy_pts)

# %%
name_update(df)
name_update(fantasy_pts)

# %%
dataframe = pd.merge(df, fantasy_pts, 'left', on='Player')

# %%
dataframe.drop(columns = ['Team_y', 'Position_y'], inplace = True)
dataframe.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position'}, inplace = True)

# %%
print(dataframe.shape)
dataframe.head(10)
# Out:
# (461, 32)
#             Player Team Position Age Games GamesStarted CompletedPasses  \
# 0     Alvin Kamara  NOR       RB  25     3            2               0
# 1   Russell Wilson  SEA       QB  32     3            3              79
# 2      Aaron Jones  GNB       RB  26     3            3               0
# 3    Calvin Ridley  ATL       WR  26     3            3               0
# 4       Josh Allen  BUF       QB  24     3            3              81
# 5      Dalvin Cook  MIN       RB  25     3            3               0
# 6  Patrick Mahomes  KAN       QB  25     3            3              82
# 7    Tyler Lockett  SEA       WR  28     3            3               0
# 8     Dak Prescott  DAL       QB  27     3            3              96
# 9       Nick Chubb  CLE       RB  25     3            3               0
#
#   PassesAttempted PassingYds PassingTDs Interceptions RushingAttempts  \
# 0               0          0          0             0              31
# 1             103        925         14             1              14
# 2               0          0          0             0              50
# 3               0          0          0             0               2
# 4             114       1038         10             1              22
# 5               0          0          0             0              48
# 6             121        898          9             0              10
# 7               0          0          0             0               0
# 8             143       1188          5             2              14
# 9               0          0          0             0              51
#
#   RushingYds RushingYdspAtt RushingTDs Targeted Receptions ReceivingYds  \
# 0        153           4.94          3       31         27          285
# 1         90           6.43          0        0          0            0
# 2        303           6.06          4       18         10           95
# 3          6           3.00          0       35         21          349
# 4         84           3.82          2        0          0            0
# 5        294           6.13          4        9          5           24
# 6         80           8.00          1        0          0            0
# 7          0                         0       29         24          259
# 8         74           5.29          3        0          0            0
# 9        292           5.73          4        3          3           17
#
#   YdspReception ReceivingTDs Fumbles LostFumbles TtlTDs TwoPTConversions  \
# 0         10.56            3       0           0      6
# 1                          0       1           0      0
# 2          9.50            1       1           0      5
# 3         16.62            4       0           0      4
# 4                          0       3           3      2
# 5          4.80            0       1           1      4                3
# 6                          0       0           0      1
# 7         10.79            4       0           0      4
# 8                          0       2           2      3
# 9          5.67            0       1           1      4
#
#   TwoPTConversionPasses FDFantasyPts PositionRank OverallRank    TTL Week_1  \
# 0                               93.3            1           1   79.8   18.7
# 1                     1        103.0            1           2  103.0   31.8
# 2                               74.8            2           3   69.8   13.6
# 3                               70.0            1           4   59.5   24.9
# 4                               94.9            2           5   94.9   28.2
# 5                               62.3            3           6   59.8   20.8
# 6                     1         87.9            3           7   87.9   20.4
# 7                               61.9            2           8   49.9    9.2
# 8                               86.9            4           9   86.9   17.6
# 9                               54.4            4          10   52.9    4.6
#
#   Week_2 Week_3
# 0   29.4   31.7
# 1   34.4   36.8
# 2   41.6   14.6
# 3   22.9   11.7
# 4   34.5   32.2
# 5   15.1   23.9
# 6   27.5   40.0
# 7   12.7   28.0
# 8   39.8   29.5
# 9   25.3   23.0

# %%
dataframe.isnull().sum()
# Out:
# Player                    0
# Team                      0
# Position                  0
# Age                       0
# Games                     0
# GamesStarted              0
# CompletedPasses           0
# PassesAttempted           0
# PassingYds                0
# PassingTDs                0
# Interceptions             0
# RushingAttempts           0
# RushingYds                0
# RushingYdspAtt            0
# RushingTDs                0
# Targeted                  0
# Receptions                0
# ReceivingYds              0
# YdspReception             0
# ReceivingTDs              0
# Fumbles                   0
# LostFumbles               0
# TtlTDs                    0
# TwoPTConversions          0
# TwoPTConversionPasses     0
# FDFantasyPts              0
# PositionRank              0
# OverallRank               0
# TTL                      10
# Week_1                   59
# Week_2                   63
# Week_3                   67
# dtype: int64

# %%
dataframe.fillna('0.0', inplace = True)

# %%
off_integers = ['Age', 'Games', 'GamesStarted', 'CompletedPasses', 'PassesAttempted', 'PassingYds', 'PassingTDs', 
            'Interceptions', 'RushingAttempts', 'RushingYds', 'RushingTDs', 'Targeted', 'Receptions', 
            'ReceivingYds', 'ReceivingTDs', 'Fumbles', 'LostFumbles', 'TtlTDs']

off_floats = ['RushingYdspAtt', 'YdspReception', 'FDFantasyPts', 'TTL','Week_1', 'Week_2', 'Week_3']

# %%
update_int_dtype(dataframe, off_integers)

# %%
two_pts = ['TwoPTConversions', 'TwoPTConversionPasses']
fill_blanks(dataframe, two_pts)
update_int_dtype(dataframe, two_pts)

# %%
update_float_dtype(dataframe, floats)

# %%
dataframe.head()
# Out:
#            Player Team Position  Age  Games  GamesStarted  CompletedPasses  \
# 0    Alvin Kamara  NOR       RB   25      3             2                0
# 1  Russell Wilson  SEA       QB   32      3             3               79
# 2     Aaron Jones  GNB       RB   26      3             3                0
# 3   Calvin Ridley  ATL       WR   26      3             3                0
# 4      Josh Allen  BUF       QB   24      3             3               81
#
#    PassesAttempted  PassingYds  PassingTDs  Interceptions  RushingAttempts  \
# 0                0           0           0              0               31
# 1              103         925          14              1               14
# 2                0           0           0              0               50
# 3                0           0           0              0                2
# 4              114        1038          10              1               22
#
#    RushingYds RushingYdspAtt  RushingTDs  Targeted  Receptions  ReceivingYds  \
# 0         153           4.94           3        31          27           285
# 1          90           6.43           0         0           0             0
# 2         303           6.06           4        18          10            95
# 3           6           3.00           0        35          21           349
# 4          84           3.82           2         0           0             0
#
#   YdspReception  ReceivingTDs  Fumbles  LostFumbles  TtlTDs  TwoPTConversions  \
# 0         10.56             3        0            0       6                 0
# 1           0.0             0        1            0       0                 0
# 2          9.50             1        1            0       5                 0
# 3         16.62             4        0            0       4                 0
# 4           0.0             0        3            3       2                 0
#
#    TwoPTConversionPasses FDFantasyPts PositionRank OverallRank    TTL Week_1  \
# 0                      0         93.3            1           1   79.8   18.7
# 1                      1        103.0            1           2  103.0   31.8
# 2                      0         74.8            2           3   69.8   13.6
# 3                      0         70.0            1           4   59.5   24.9
# 4                      0         94.9            2           5   94.9   28.2
#
#   Week_2 Week_3
# 0   29.4   31.7
# 1   34.4   36.8
# 2   41.6   14.6
# 3   22.9   11.7
# 4   34.5   32.2

# %% [markdown]
# ## Defense Stats

# %%
defense.head()
# Out:
#                    Team Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed Yds_p_Play  \
# 0      Baltimore Ravens              22                       125        4.9
# 1    Kansas City Chiefs              40                       137        6.1
# 2    Indianapolis Colts              45                       154        4.4
# 3   San Francisco 49ers              46                       189        4.8
# 4  Los Angeles Chargers              57                       188        5.4
#
#   Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs Passing_Att  \
# 0     610          44         189               4.3           0          75
# 1     839          66         301               4.6           3          65
# 2     676          70         280                 4           1          75
# 3     912          80         350               4.4           2         104
# 4   1,011          71         328               4.6           1         111
#
#   Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds Passing_TDs  \
# 0               6.2          46             10.1         464           2
# 1               8.7          42             13.4         564           2
# 2               6.1          47              9.7         454           4
# 3               5.7          64              9.2         588           2
# 4               6.6          72             10.1         730           3
#
#   RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles Sacks
# 0      3     2      66.7%             5             2       3     6
# 1      6     5      83.3%             2             2       0     6
# 2      6     4      66.7%             6             6       0     9
# 3      4     2        50%             4             2       2     5
# 4      9     2      22.2%             2             1       1     6

# %%
def_fantasy = fantasy_pts[fantasy_pts['Position'] == 'DST']

# %%
defense_df = pd.merge(defense, def_fantasy, 'left', left_on = 'Team', right_on = 'Player')

# %%
defense_df.head()
# Out:
#                  Team_x Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed Yds_p_Play  \
# 0      Baltimore Ravens              22                       125        4.9
# 1    Kansas City Chiefs              40                       137        6.1
# 2    Indianapolis Colts              45                       154        4.4
# 3   San Francisco 49ers              46                       189        4.8
# 4  Los Angeles Chargers              57                       188        5.4
#
#   Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs Passing_Att  \
# 0     610          44         189               4.3           0          75
# 1     839          66         301               4.6           3          65
# 2     676          70         280                 4           1          75
# 3     912          80         350               4.4           2         104
# 4   1,011          71         328               4.6           1         111
#
#   Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds Passing_TDs  \
# 0               6.2          46             10.1         464           2
# 1               8.7          42             13.4         564           2
# 2               6.1          47              9.7         454           4
# 3               5.7          64              9.2         588           2
# 4               6.6          72             10.1         730           3
#
#   RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles Sacks  \
# 0      3     2      66.7%             5             2       3     6
# 1      6     5      83.3%             2             2       0     6
# 2      6     4      66.7%             6             6       0     9
# 3      4     2        50%             4             2       2     5
# 4      9     2      22.2%             2             1       1     6
#
#                  Player Team_y Position   TTL Week_1 Week_2 Week_3
# 0      Baltimore Ravens    BAL      DST  31.0   15.0   15.0    1.0
# 1    Kansas City Chiefs     KC      DST  19.0    7.0    5.0    7.0
# 2    Indianapolis Colts    IND      DST  45.0    4.0   15.0   26.0
# 3   San Francisco 49ers     SF      DST  21.0    4.0    5.0   12.0
# 4  Los Angeles Chargers    LAC      DST  14.0   11.0    1.0    2.0

# %%
defense_df.drop(columns=['Player', 'Team_y', 'Position'], inplace=True)
defense_df.rename(columns={'Team_x': 'Team'}, inplace=True)

# %%
defense_df.head()
# Out:
#                    Team Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed Yds_p_Play  \
# 0      Baltimore Ravens              22                       125        4.9
# 1    Kansas City Chiefs              40                       137        6.1
# 2    Indianapolis Colts              45                       154        4.4
# 3   San Francisco 49ers              46                       189        4.8
# 4  Los Angeles Chargers              57                       188        5.4
#
#   Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs Passing_Att  \
# 0     610          44         189               4.3           0          75
# 1     839          66         301               4.6           3          65
# 2     676          70         280                 4           1          75
# 3     912          80         350               4.4           2         104
# 4   1,011          71         328               4.6           1         111
#
#   Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds Passing_TDs  \
# 0               6.2          46             10.1         464           2
# 1               8.7          42             13.4         564           2
# 2               6.1          47              9.7         454           4
# 3               5.7          64              9.2         588           2
# 4               6.6          72             10.1         730           3
#
#   RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles Sacks   TTL  \
# 0      3     2      66.7%             5             2       3     6  31.0
# 1      6     5      83.3%             2             2       0     6  19.0
# 2      6     4      66.7%             6             6       0     9  45.0
# 3      4     2        50%             4             2       2     5  21.0
# 4      9     2      22.2%             2             1       1     6  14.0
#
#   Week_1 Week_2 Week_3
# 0   15.0   15.0    1.0
# 1    7.0    5.0    7.0
# 2    4.0   15.0   26.0
# 3    4.0    5.0   12.0
# 4   11.0    1.0    2.0

# %%
nocomma = defense_df['Ttl_Yds'][3]
nocomma.split(',')
# Out:
# ['912']

# %%
comma = defense_df['Ttl_Yds'][4]
len(comma.split(','))
# Out:
# 2

# %%
one, two = comma.split(',')
one + two
# Out:
# '1011'

# %%
for column in def_int:
    for i in range(len(defense_df[column])):
        item = defense_df[column][i]
        if len(item.split(',')) > 1:
            one, two = item.split(',')
            defense_df[column][i] = one + two

# %%
defense_df.head()
# Out:
#                    TEAM  Ttl_Pts_Allowed  Ttl_Offense_Plays_Allowed  \
# 0      Baltimore Ravens               22                        125
# 1    Kansas City Chiefs               40                        137
# 2    Indianapolis Colts               45                        154
# 3   San Francisco 49ers               46                        189
# 4  Los Angeles Chargers               57                        188
#
#   Yds_p_Play  Ttl_Yds  Rushing_Att  Rushing_Yds Rushing_Yds_p_Att  \
# 0        4.9      610           44          189               4.3
# 1        6.1      839           66          301               4.6
# 2        4.4      676           70          280                 4
# 3        4.8      912           80          350               4.4
# 4        5.4     1011           71          328               4.6
#
#    Rushing_TDs  Passing_Att Passing_Yds_p_Att  Completions Yds_p_Completion  \
# 0            0           75               6.2           46             10.1
# 1            3           65               8.7           42             13.4
# 2            1           75               6.1           47              9.7
# 3            2          104               5.7           64              9.2
# 4            1          111               6.6           72             10.1
#
#    Passing_Yds  Passing_TDs  RZ_Att  RZ_TD RZ_Percent  Ttl_Turnovers  \
# 0          464            2       3      2      66.7%              5
# 1          564            2       6      5      83.3%              2
# 2          454            4       6      4      66.7%              6
# 3          588            2       4      2        50%              4
# 4          730            3       9      2      22.2%              2
#
#    Interceptions  Fumbles  Sacks   TTL Week_1 Week_2 Week_3
# 0              2        3      6  31.0   15.0   15.0    1.0
# 1              2        0      6  19.0    7.0    5.0    7.0
# 2              6        0      9  45.0    4.0   15.0   26.0
# 3              2        2      5  21.0    4.0    5.0   12.0
# 4              1        1      6  14.0   11.0    1.0    2.0

# %%
def_int = ['Ttl_Pts_Allowed', 'Ttl_Offense_Plays_Allowed', 'Ttl_Yds', 'Rushing_Att', 'Rushing_Yds', 'Rushing_TDs', 
           'Passing_Att', 'Completions', 'Passing_Yds', 'Passing_TDs', 'RZ_Att', 'RZ_TD', 'Ttl_Turnovers', 
           'Interceptions', 'Fumbles', 'Sacks']

def_floats = ['Yds_p_Play', 'Rushing_Yds_p_Att', 'Passing_Yds_p_Att', 'Yds_p_Completion', 'TTL', 'Week_1', 
              'Week_2', 'Week_3']

# %%
update_int_dtype(defense_df, def_int)

# %%
for column in def_floats:
    for i in range(len(defense_df[column])):
        item = defense_df[column][i]
        if len(item) < 3:
            defense_df[column][i] = item + '.0'
        else:
            defense_df[column][i] = item
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for column in def_floats:
    for i in range(len(defense_df[column])):
        item = str(defense_df[column][i])
        ones, tenths = item.split('.')
        ones = int(ones)
        tenths = int(tenths) * .1
        defense_df[column][i] = ones + tenths
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
defense_df['RZ_Percent'] = defense_df['RZ_Percent'].map(lambda x: x.strip('%'))

# %%
for column in defense_df['RZ_Percent']:
    for i in range(len(defense_df['RZ_Percent'])):
        item = defense_df['RZ_Percent'][i]
        if len(item) < 3:
            defense_df['RZ_Percent'][i] = item + '.0'
        else:
            defense_df['RZ_Percent'][i] = item
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(defense_df['RZ_Percent'])):
    item = str(defense_df['RZ_Percent'][i])
    ones, tenths = item.split('.')
    ones = int(ones)
    tenths = int(tenths) * .1
    defense_df['RZ_Percent'][i] = ones + tenths
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataframe.to_pickle('players')
defense_df.to_pickle('defense')
