# %% [markdown]
# # Defense

# %%
import pandas as pd

# %%
df = pd.read_pickle('defense')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# setting format for readability
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.head()
# Out:
#             PLAYER POSITION TEAM GP STK ATK CMB INT YDS LNG TD FMB FREC FTD  \
# 0  Jaire Alexander       CB   GB  1   4   1   5   1  -4  -4  0   0    0   0
# 1   Chidobe Awuzie       CB  DAL  1   2   0   2   1   0   0  0   0    0   0
# 2    Quandre Diggs       SS  SEA  1   3   1   4   1   0   0  0   0    0   0
# 3      Kyle Fuller       CB  CHI  1   3   1   4   1   5   5  0   0    0   0
# 4  Stephon Gilmore       CB   NE  1   4   1   5   1  15  15  0   0    0   0
#
#    SCK PDEF SFTY
# 0  1.0    1    1
# 1  0.0    1    0
# 2  0.0    2    0
# 3  0.0    1    0
# 4  0.0    1    0

# %%
df.shape
# Out:
# (509, 17)

# %%
df.dtypes
# Out:
# PLAYER      object
# POSITION    object
# TEAM        object
# GP          object
# STK         object
# ATK         object
# CMB         object
# INT         object
# YDS         object
# LNG         object
# TD          object
# FMB         object
# FREC        object
# FTD         object
# SCK         object
# PDEF        object
# SFTY        object
# dtype: object

# %%
columns = ['GP', 'STK', 'ATK', 'CMB', 'INT', 'YDS', 'LNG', 'TD', 'FMB', 'FREC', 'FTD', 'PDEF', 'SFTY']

# %%
dash = df['LNG'][508]
val = dash

# %%
for column in columns:
    for i in range(len(df[column])):
        item = df[column][i]
        if item == val:
            df[column][i] = '0'
        else:
            df[column][i] = item

# %%
for column in columns:
    df[column] = df[column].map(lambda x: int(x))

# %%
df.dtypes
# Out:
# PLAYER      object
# POSITION    object
# TEAM        object
# GP           int64
# STK          int64
# ATK          int64
# CMB          int64
# INT          int64
# YDS          int64
# LNG          int64
# TD           int64
# FMB          int64
# FREC         int64
# FTD          int64
# SCK         object
# PDEF         int64
# SFTY         int64
# dtype: object

# %%
df['SCK'][299]
# Out:
# '—'

# %%
for i in range(len(df['SCK'])):
    item = df['SCK'][i]
    if item == val:
        df['SCK'][i] = '0.0'
    else:
        df['SCK'][i] = item
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df['SCK'].value_counts()
# Out:
# 0.0    439
# 1.0     54
# 0.5      9
# 1.5      4
# 2.0      3
# Name: SCK, dtype: int64

# %%
for i in range(len(df['SCK'])):
    item = str(df['SCK'][i])
    ones, tenths = item.split('.')
    ones = int(ones)
    tenths = int(tenths) * .1
    df['SCK'][i] = ones + tenths
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['SCK']
# Out:
# 0     1.00
# 1     0.00
# 2     0.00
# 3     0.00
# 4     0.00
# 5     0.00
# 6     0.00
# 7     0.00
# 8     0.00
# 9     0.00
# 10    0.00
# 11    0.00
# 12    0.00
# 13    0.00
# 14    0.00
# 15    0.00
# 16    0.00
# 17    0.00
# 18    0.00
# 19    0.00
# 20    0.50
# 21    1.00
# 22    0.00
# 23    1.00
# 24    1.00
# 25    1.00
# 26    0.00
# 27    1.00
# 28    0.00
# 29    0.00
# 30    0.00
# 31    0.00
# 32    0.00
# 33    0.00
# 34    0.00
# 35    0.00
# 36    0.00
# 37    0.00
# 38    0.00
# 39    0.00
# 40    0.00
# 41    0.00
# 42    0.00
# 43    0.00
# 44    0.00
# 45    0.00
# 46    0.00
# 47    0.00
# 48    0.00
# 49    0.00
# 50    0.00
# 51    0.00
# 52    0.00
# 53    0.00
# 54    0.00
# 55    0.00
# 56    0.00
# 57    0.00
# 58    0.00
# 59    0.00
# 60    0.00
# 61    0.00
# 62    0.00
# 63    0.00
# 64    0.00
# 65    0.00
# 66    0.00
# 67    0.00
# 68    0.00
# 69    0.00
# 70    1.00
# 71    0.00
# 72    0.00
# 73    0.00
# 74    0.00
# 75    0.00
# ...

# %%
df['SCK'][0] + df['SCK'][1]
# Out:
# 1.0

# %%
grouped = df[['TEAM', 'STK', 'ATK', 'CMB', 'INT', 'YDS', 'LNG', 'TD', 'FMB', 'FREC', 
              'FTD', 'SCK', 'PDEF', 'SFTY']].groupby('TEAM').sum()
grouped.sort_values('TD', ascending=False)
# Out:
#       STK  ATK  CMB  INT  YDS  LNG  TD  FMB  FREC  FTD  PDEF  SFTY
# TEAM
# NO     47   12   59    2   53   53   1    1     1    0     4     0
#         8    1    9    1    0    0   0    0     0    0     2     0
# LAC    45   17   62    1    0    0   0    1     1    0     3     0
# TEN    36   13   49    0    0    0   0    2     1    0     2     0
# TB     40   22   62    0    0    0   0    0     0    0     3     0
# SF     48   24   72    1   16   16   0    2     0    0     5     0
# SEA    37   21   58    1    0    0   0    1     1    0     6     0
# PIT    40   11   51    2    0    0   0    0     0    0     5     0
# PHI    40   19   59    0    0    0   0    1     0    0     4     0
# NYJ    53   25   78    0    0    0   0    2     2    0     6     0
# NYG    42   19   61    0    0    0   0    1     1    0     3     0
# NE     48   20   68    2   20   20   0    0     0    0     3     0
# MIN    50   12   62    0    0    0   0    1     0    0     1     0
# ...

# %%
df.columns
# Out:
# Index(['PLAYER', 'POSITION', 'TEAM', 'GP', 'STK', 'ATK', 'CMB', 'INT', 'YDS',
#        'LNG', 'TD', 'FMB', 'FREC', 'FTD', 'SCK', 'PDEF', 'SFTY'],
#       dtype='object')
