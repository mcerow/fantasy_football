# %% [markdown]
# # Week 14 -- Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %% [markdown]
# ## Functions

# %%
def check_names(df1, df2):
    """
    This funciton compares the list of names from one dataframe to another and updates where the names do not match 
    so they will merge correctly.
    
    Parameters:
        df1: first dataframe to compare to; this should be the dataframe on the left that you will join with when 
        they merge.
        df2: second dataframe, should be the dataframe on the right for the later merge.
        
    Returns:
        Updated name list for df2 that should match df1.
    """
    
    df_players = list(df1['Player'])    
    for i in range(len(df2['Player'])):
        name = df2['Player'][i]
        split_name = name.split(' ')
        if (split_name[0] + ' ' + split_name[1]) in df_players:
            df2['Player'][i] = split_name[0] + ' ' + split_name[1]
        else:
            df2['Player'][i] = name

# %%
def name_update(dataframe, column):
    """
    This function updates a column in a dataframe by stripping any excess spaces surrounding the observation.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column: the column you want to update.
    
    Returns:
        Updated dataframe column.    
    """
    dataframe[column] = dataframe[column].map(lambda x: x.strip())

# %%
def update_int_dtype(dataframe, column_list):
    """
    This function updates the data type for a list of columns to integer.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe column data types to integer.   
    """
    for column in column_list:
        dataframe[column] = dataframe[column].map(lambda x: int(x))

# %%
def update_float_dtype(dataframe, column_list):
    """
    This function takes a dataframe object and converts it to a float.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
    
    Returns:
        Updated dataframe column data types to a float.  
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = '0.0'
            else:
                dataframe[column][i] = item 
            updated_item = str(dataframe[column][i])
            ones, tenths = updated_item.split('.')
            ones = int(ones)
            tenths = int(tenths) * .1
            dataframe[column][i] = ones + tenths
        dataframe[column] = dataframe[column].map(lambda x: float(x))

# %%
def fill_blanks(dataframe, column_list):
    """
    This function fills blank values with 0. This should be used for a column that will be an integer.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.    
    
    Returns:
        Updated dataframe columns with filled values.      
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == '':
                dataframe[column][i] = 0
            else:
                dataframe[column][i] = item

# %%
def remove_comma(dataframe, column_list):
    """
    This function removes the comma from a value in a column.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe columns less any commas that might appear.    
    """  
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if len(item.split(',')) > 1:
                one, two = item.split(',')
                dataframe[column][i] = one + two

# %%
def adjust_float(dataframe, column_list):
    """
    This function adjusts values in a column to be workable with the 'update_float_dtype' function.
    
    Parameters:
        dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe columns with objects with a decimal point value behind it.    
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if len(item) < 3:
                dataframe[column][i] = item + '.0'
            else:
                dataframe[column][i] = item

# %%
def update_percent(dataframe, column):
    """
    This function updates a column with a percent sign so it can be manipulated into a float with the 
    'update_float_dtype' function.
    
    Parameters:
       dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        
    Returns:
        Updated dataframe column with no percent sign and added decimal point where needed.     
    """
    dataframe[column] = dataframe[column].map(lambda x: x.strip('%'))
    for i in range(len(dataframe[column])):
        item = dataframe[column][i]
        if len(item) < 3:
            dataframe[column][i] = item + '.0'
        else:
            dataframe[column][i] = item

# %%
def replace_dash(dataframe, column_list, dash):
    """
    This function replaces a - in a dataframe so datatypes can then be updated.
    
    Parameters:
       dataframe: the dataframe you want to update.
        column_list: list of columns to iterate through.
        dash: set to a value in a specific column in the dataframe.
        
    Returns:
        Updated dataframe column with no percent sign and added decimal point where needed. 
    """
    for column in column_list:
        for i in range(len(dataframe[column])):
            item = dataframe[column][i]
            if item == dash:
                dataframe[column][i] = '0'
            else:
                dataframe[column][i] = item

# %% [markdown]
# ## Read in Collected Data

# %%
df = pd.read_pickle('player_stats')
fantasy_pts = pd.read_pickle('fantasy_weeks')
defense = pd.read_pickle('defense_data')
kicking = pd.read_pickle('kicking_data')

# %% [markdown]
# ## Merge Last Week Fantasy Pts with this Week

# %%
no_games = 14

# %%
lastwk = pd.read_pickle('fantweeks_1_' + str(no_games - 1))
lastwk.head()
# Out:
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  317.9   27.3   33.1   24.7   23.1   27.3
# 1  Patrick Mahomes II   KC       QB  312.6   20.4   27.5   40.0   20.2   30.7
# 2      Russell Wilson  SEA       QB  298.5   31.8   34.4   36.8   21.9   25.5
# 3          Josh Allen  BUF       QB  295.6   28.2   34.5   32.2   25.4   18.3
# 4       Aaron Rodgers   GB       QB  285.8   30.8   18.2   24.5   29.6    NaN
#
#   Week_6 Week_7 Week_8 Week_9 Week_10 Week_11 Week_12 Week_13
# 0   28.9   38.1    NaN   37.9    30.9    20.3     8.9    17.4
# 1   20.6   12.0   36.6   30.9     NaN    22.5    31.3    19.3
# 2    NaN   32.9   28.7   24.1    11.9    20.1    14.4    16.0
# 3   16.1   16.4   13.5   36.0    28.4     NaN    16.5    30.1
# 4    5.8   27.3   22.5   28.9    26.4    22.7    25.6    23.5

# %%
fantasy_pts = pd.merge(fantasy_pts, lastwk, 'left', on='Player')
fantasy_pts.head()
# Out:
#                Player Team_x Position_x  TTL_x Week_14 Team_y Position_y  \
# 0        Kyler Murray    ARI         QB  336.4    18.5    ARI         QB
# 1  Patrick Mahomes II     KC         QB  334.2    21.6     KC         QB
# 2      Russell Wilson    SEA         QB  321.6    23.1    SEA         QB
# 3       Aaron Rodgers     GB         QB  316.7    30.9     GB         QB
# 4          Josh Allen    BUF         QB  314.9    19.3    BUF         QB
#
#    TTL_y Week_1 Week_2 Week_3 Week_4 Week_5 Week_6 Week_7 Week_8 Week_9  \
# 0  317.9   27.3   33.1   24.7   23.1   27.3   28.9   38.1    NaN   37.9
# 1  312.6   20.4   27.5   40.0   20.2   30.7   20.6   12.0   36.6   30.9
# 2  298.5   31.8   34.4   36.8   21.9   25.5    NaN   32.9   28.7   24.1
# 3  285.8   30.8   18.2   24.5   29.6    NaN    5.8   27.3   22.5   28.9
# 4  295.6   28.2   34.5   32.2   25.4   18.3   16.1   16.4   13.5   36.0
#
#   Week_10 Week_11 Week_12 Week_13
# 0    30.9    20.3     8.9    17.4
# 1     NaN    22.5    31.3    19.3
# 2    11.9    20.1    14.4    16.0
# 3    26.4    22.7    25.6    23.5
# 4    28.4     NaN    16.5    30.1

# %%
fantasy_pts.drop(columns=['Team_y', 'Position_y', 'TTL_y'], inplace=True)
fantasy_pts.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position', 'TTL_x': 'TTL'}, inplace = True)
fantasy_pts.columns
# Out:
# Index(['Player', 'Team', 'Position', 'TTL', 'Week_14', 'Week_1', 'Week_2',
#        'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9',
#        'Week_10', 'Week_11', 'Week_12', 'Week_13'],
#       dtype='object')

# %%
fantasy_pts = fantasy_pts[['Player', 'Team', 'Position', 'TTL', 'Week_1', 'Week_2', 'Week_3', 'Week_4', 'Week_5', 
                           'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10', 'Week_11', 'Week_12', 'Week_13', 
                           'Week_14']]
fantasy_pts.head()
# Out:
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  336.4   27.3   33.1   24.7   23.1   27.3
# 1  Patrick Mahomes II   KC       QB  334.2   20.4   27.5   40.0   20.2   30.7
# 2      Russell Wilson  SEA       QB  321.6   31.8   34.4   36.8   21.9   25.5
# 3       Aaron Rodgers   GB       QB  316.7   30.8   18.2   24.5   29.6    NaN
# 4          Josh Allen  BUF       QB  314.9   28.2   34.5   32.2   25.4   18.3
#
#   Week_6 Week_7 Week_8 Week_9 Week_10 Week_11 Week_12 Week_13 Week_14
# 0   28.9   38.1    NaN   37.9    30.9    20.3     8.9    17.4    18.5
# 1   20.6   12.0   36.6   30.9     NaN    22.5    31.3    19.3    21.6
# 2    NaN   32.9   28.7   24.1    11.9    20.1    14.4    16.0    23.1
# 3    5.8   27.3   22.5   28.9    26.4    22.7    25.6    23.5    30.9
# 4   16.1   16.4   13.5   36.0    28.4     NaN    16.5    30.1    19.3

# %%
print(fantasy_pts.shape)
# Out:
# (690, 18)

# %% [markdown]
# ### Pickle Combined DataFrame for Next Week

# %%
fantasy_pts.to_pickle('fantweeks_1_' + str(no_games))

# %% [markdown]
# ## Merge Offensive Players & Weekly Fantasy Pts

# %%
print(df.shape)
df.head()
# Out:
# (601, 28)
#           Player Team Position Age Games GamesStarted CompletedPasses  \
# 0    Dalvin Cook  MIN       RB  25    12           12               0
# 1  Derrick Henry  TEN       RB  26    13           13               0
# 2    Tyreek Hill  KAN       WR  26    13           13               0
# 3   Alvin Kamara  NOR       RB  25    13            8               0
# 4   Travis Kelce  KAN       TE  31    13           13               1
#
#   PassesAttempted PassingYds PassingTDs Interceptions RushingAttempts  \
# 0               0          0          0             0             273
# 1               0          0          0             0             297
# 2               0          0          0             0              12
# 3               0          0          0             0             154
# 4               2          4          0             0               0
#
#   RushingYds RushingYdspAtt RushingTDs Targeted Receptions ReceivingYds  \
# 0       1352           4.95         14       47         37          322
# 1       1532           5.16         14       29         17          109
# 2        122          10.17          2      119         77         1158
# 3        723           4.69         10       96         77          699
# 4          0                         0      120         90         1250
#
#   YdspReception ReceivingTDs Fumbles LostFumbles TtlTDs TwoPTConversions  \
# 0          8.70            1       4           3     15                3
# 1          6.41            0       1           1     14
# 2         15.04           14       1           0     16
# 3          9.08            4       1           0     14
# 4         13.89            9       1           1      9
#
#   TwoPTConversionPasses FDFantasyPts PositionRank OverallRank
# 0                              275.9            1           1
# 1                              254.6            2           2
# 2                              262.5            1           3
# 3                              264.7            3           4
# 4                              222.2            1           5

# %%
print(fantasy_pts.shape)
fantasy_pts.head()
# Out:
# (690, 18)
#                Player Team Position    TTL Week_1 Week_2 Week_3 Week_4 Week_5  \
# 0        Kyler Murray  ARI       QB  336.4   27.3   33.1   24.7   23.1   27.3
# 1  Patrick Mahomes II   KC       QB  334.2   20.4   27.5   40.0   20.2   30.7
# 2      Russell Wilson  SEA       QB  321.6   31.8   34.4   36.8   21.9   25.5
# 3       Aaron Rodgers   GB       QB  316.7   30.8   18.2   24.5   29.6    NaN
# 4          Josh Allen  BUF       QB  314.9   28.2   34.5   32.2   25.4   18.3
#
#   Week_6 Week_7 Week_8 Week_9 Week_10 Week_11 Week_12 Week_13 Week_14
# 0   28.9   38.1    NaN   37.9    30.9    20.3     8.9    17.4    18.5
# 1   20.6   12.0   36.6   30.9     NaN    22.5    31.3    19.3    21.6
# 2    NaN   32.9   28.7   24.1    11.9    20.1    14.4    16.0    23.1
# 3    5.8   27.3   22.5   28.9    26.4    22.7    25.6    23.5    30.9
# 4   16.1   16.4   13.5   36.0    28.4     NaN    16.5    30.1    19.3

# %%
check_names(df, fantasy_pts)

# %%
name_update(df, 'Player')
name_update(fantasy_pts, 'Player')

# %%
offense = pd.merge(df, fantasy_pts, 'left', on='Player')

# %%
offense.drop(columns = ['Team_y', 'Position_y'], inplace = True)
offense.rename(columns = {'Team_x': 'Team', 'Position_x': 'Position'}, inplace = True)

# %%
print(offense.shape)
offense.head(10)
# Out:
# (601, 43)
#             Player Team Position Age Games GamesStarted CompletedPasses  \
# 
# PassesAttempted            0
# PassingYds                 0
# PassingTDs                 0
# Interceptions              0
# RushingAttempts            0
# RushingYds                 0
# RushingYdspAtt             0
# RushingTDs                 0
# Targeted                   0
# Receptions                 0
# ReceivingYds               0
# YdspReception              0
# ReceivingTDs               0
# Fumbles                    0
# LostFumbles                0
# TtlTDs                     0
# TwoPTConversions           0
# TwoPTConversionPasses      0
# FDFantasyPts               0
# PositionRank               0
# OverallRank                0
# TTL                       24
# Week_1                   191
# Week_2                   194
# Week_3                   195
# Week_4                   221
# Week_5                   250
# Week_6                   247
# Week_7                   251
# Week_8                   296
# Week_9                   302
# Week_10                  303
# Week_11                  301
# Week_12                  254
# Week_13                  279
# Week_14                  261
# dtype: int64

# %%
offense.fillna('0.0', inplace = True)

# %%
off_integers = ['Age', 'Games', 'GamesStarted', 'CompletedPasses', 'PassesAttempted', 'PassingYds', 'PassingTDs', 
            'Interceptions', 'RushingAttempts', 'RushingYds', 'RushingTDs', 'Targeted', 'Receptions', 
            'ReceivingYds', 'ReceivingTDs', 'Fumbles', 'LostFumbles', 'TtlTDs']

off_floats = ['RushingYdspAtt', 'YdspReception', 'FDFantasyPts', 'TTL','Week_1', 'Week_2', 'Week_3', 'Week_4', 
              'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10', 'Week_11', 'Week_12', 'Week_13', 
              'Week_14']

# %%
fill_blanks(offense, off_integers)

# %%
update_int_dtype(offense, off_integers)

# %%
two_pts = ['TwoPTConversions', 'TwoPTConversionPasses']
fill_blanks(offense, two_pts)
update_int_dtype(offense, two_pts)

# %%
update_float_dtype(offense, off_floats)

# %%
offense.head()
# Out:
#           Player Team Position  Age  Games  GamesStarted  CompletedPasses  \
# 0    Dalvin Cook  MIN       RB   25     12            12                0
# 1  Derrick Henry  TEN       RB   26     13            13                0
# 2    Tyreek Hill  KAN       WR   26     13            13                0
# 3   Alvin Kamara  NOR       RB   25     13             8                0
# 4   Travis Kelce  KAN       TE   31     13            13                1
#
#    PassesAttempted  PassingYds  PassingTDs  Interceptions  RushingAttempts  \
# 0                0           0           0              0              273
# 1                0           0           0              0              297
# 2                0           0           0              0               12
# 3                0           0           0              0              154
# 4                2           4           0              0                0
#
#    RushingYds  RushingYdspAtt  RushingTDs  Targeted  Receptions  ReceivingYds  \
# 0        1352            13.5          14        47          37           322
# 1        1532             6.6          14        29          17           109
# 2         122            11.7           2       119          77          1158
# 3         723            10.9          10        96          77           699
# 4           0             0.0           0       120          90          1250
#
#    YdspReception  ReceivingTDs  Fumbles  LostFumbles  TtlTDs  \
# 0           15.0             1        4            3      15
# 1           10.1             0        1            1      14
# 2           15.4            14        1            0      16
# 3            9.8             4        1            0      14
# 4           21.9             9        1            1       9
#
#    TwoPTConversions  TwoPTConversionPasses  FDFantasyPts PositionRank  \
# 0                 3                      0         275.9            1
# 1                 0                      0         254.6            2
# 2                 0                      0         262.5            1
# 3                 0                      0         264.7            3
# 4                 0                      0         222.2            1
#
#   OverallRank   TTL  Week_1  Week_2  Week_3  Week_4  Week_5  Week_6  Week_7  \
# 0           1 257.4    20.8    15.1    23.9    26.6    14.9     0.0     0.0
# 1           2 246.1    13.1     8.4    25.0     0.0    18.3    38.4    13.2
# 2           3 224.0    10.6    16.8    16.2    12.4    15.3     2.5    11.5
# 3           4 226.2    18.7    29.4    31.7    17.9    11.9     0.0    14.8
# 4           5 177.2    11.0    15.0     8.7     7.0    16.8    16.5     3.1
#
#    Week_8  Week_9  Week_10  Week_11  Week_12  Week_13  Week_14
# 0    46.6    37.2     11.2     20.0      6.2     17.9     17.0
# 1    17.2     6.8     10.9     19.2     36.5      4.9     34.2
# 2    21.8    24.1      0.0     16.0     44.9      8.8     23.1
# 3    16.3    10.9     27.8     10.5      5.2     15.7     15.4
# 4    16.9    15.9      0.0     18.9      8.2     19.6     19.6

# %%
team_dict = {'LAR': 'Los Angeles Rams', 
             'SEA': 'Seattle Seahawks', 
             'BAL': 'Baltimore Ravens', 
             'KAN': 'Kansas City Chiefs', 
             'JAX': 'Jacksonville Jaguars', 
             'DET': 'Detroit Lions', 
             'PIT': 'Pittsburgh Steelers', 
             'MIN': 'Minnesota Vikings', 
             'CHI': 'Chicago Bears', 
             'ATL': 'Atlanta Falcons', 
             'BUF': 'Buffalo Bills', 
             'GNB': 'Green Bay Packers', 
             'MIA': 'Miami Dolphins', 
             'CLE': 'Cleveland Browns', 
             'CAR': 'Carolina Panthers', 
             'DAL': 'Dallas Cowboys', 
             'ARI': 'Arizona Cardinals', 
             'HOU': 'Houston Texans', 
             'NYG': 'New York Giants', 
             'WAS': 'Washington Football Team', 
             'IND': 'Indianapolis Colts', 
             'LVR': 'Las Vegas Raiders', 
             'DEN': 'Denver Broncos', 
             'TEN': 'Tennessee Titans', 
             'NWE': 'New England Patriots', 
             'CIN': 'Cincinnati Bengals', 
             'NYJ': 'New York Jets', 
             'LAC': 'Los Angeles Chargers', 
             'PHI': 'Philadelphia Eagles', 
             'TAM': 'Tampa Bay Buccaneers', 
             'NOR': 'New Orleans Saints', 
             'SFO': 'San Francisco 49ers'}

team_names = pd.DataFrame()
team_names['Team'] = list(team_dict.keys())
team_names['Long_Name'] = list(team_dict.values())
team_names.head()
# Out:
#   Team             Long_Name
# 0  LAR      Los Angeles Rams
# 1  SEA      Seattle Seahawks
# 2  BAL      Baltimore Ravens
# 3  KAN    Kansas City Chiefs
# 4  JAX  Jacksonville Jaguars

# %% [markdown]
# ## Defense Stats

# %%
defense.head()
# Out:
#                   Team  GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0  Pittsburgh Steelers  13             237                       811
# 1       Miami Dolphins  13             245                       821
# 2     Los Angeles Rams  13             246                       815
# 3   New Orleans Saints  13             265                       780
# 4     Baltimore Ravens  13             273                       862
#
#   Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 0        4.9   3,940         314       1,312               4.2           7
# 1        5.7   4,710         341       1,563               4.6          14
# 2        4.6   3,716         315       1,224               3.9          10
# 3          5   3,879         312       1,159               3.7           7
# 4        5.3   4,545         329       1,477               4.5          12
#
#   Passing_Att Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds  \
# 0         452               5.3         253             11.6       2,628
# 1         446               6.6         281             12.2       3,147
# 2         458                 5         286              9.7       2,492
# 3         432               5.8         262             11.2       2,720
# 4         505               5.8         328               10       3,068
#
#   Passing_TDs RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles  \
# 0          19     35    19      54.3%            25            17       8
# 1          16     38    22      57.9%            25            16       9
# 2          14     37    22      59.5%            21            13       8
# 3          22     36    24      66.7%            20            13       7
# 4          19     38    25      65.8%            19             8      11
#
#   Sacks
# 0    45
# 1    34
# 2    42
# 3    36
# 4    28

# %%
def_fantasy = fantasy_pts[fantasy_pts['Position'] == 'DST']

# %%
defense_df = pd.merge(defense, def_fantasy, 'left', left_on = 'Team', right_on = 'Player')

# %%
defense_df.head()
# Out:
#                 Team_x  GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 0  Pittsburgh Steelers  13             237                       811
# 1       Miami Dolphins  13             245                       821
# 2     Los Angeles Rams  13             246                       815
# 3   New Orleans Saints  13             265                       780
# 4     Baltimore Ravens  13             273                       862
#
#   Yds_p_Play Ttl_Yds Rushing_Att Rushing_Yds Rushing_Yds_p_Att Rushing_TDs  \
# 0        4.9   3,940         314       1,312               4.2           7
# 1        5.7   4,710         341       1,563               4.6          14
# 2        4.6   3,716         315       1,224               3.9          10
# 3          5   3,879         312       1,159               3.7           7
# 4        5.3   4,545         329       1,477               4.5          12
#
#   Passing_Att Passing_Yds_p_Att Completions Yds_p_Completion Passing_Yds  \
# 0         452               5.3         253             11.6       2,628
# 1         446               6.6         281             12.2       3,147
# 2         458                 5         286              9.7       2,492
# 3         432               5.8         262             11.2       2,720
# 4         505               5.8         328               10       3,068
#
#   Passing_TDs RZ_Att RZ_TD RZ_Percent Ttl_Turnovers Interceptions Fumbles  \
# 0          19     35    19      54.3%            25            17       8
# 1          16     38    22      57.9%            25            16       9
# 2          14     37    22      59.5%            21            13       8
# 3          22     36    24      66.7%            20            13       7
# 4          19     38    25      65.8%            19             8      11
#
#   Sacks               Player Team_y Position    TTL Week_1 Week_2 Week_3  \
# 0    45  Pittsburgh Steelers    PIT      DST  133.0    8.0   13.0    7.0
# 1    34       Miami Dolphins    MIA      DST  126.0    2.0    2.0   12.0
# 2    42     Los Angeles Rams    LAR      DST  123.0    4.0    7.0    4.0
# 3    36   New Orleans Saints     NO      DST   99.0   15.0    4.0   -3.0
# 4    28     Baltimore Ravens    BAL      DST  110.0   15.0   15.0    1.0
#
#   Week_4 Week_5 Week_6 Week_7 Week_8 Week_9 Week_10 Week_11 Week_12 Week_13  \
# 0   10.0    8.0   18.0    2.0   18.0    7.0    12.0    17.0    14.0     3.0
# 1    3.0   12.0   15.0    NaN   17.0    8.0     4.0     5.0    14.0    14.0
# 2   11.0   12.0    0.0   15.0    5.0    NaN    13.0     5.0    15.0    11.0
# 3    4.0    3.0    NaN    1.0    7.0   16.0    14.0    16.0    14.0     6.0
# 4    6.0   26.0    7.0    NaN    4.0   14.0     1.0     3.0     8.0     4.0
#
#   Week_14
# 0     6.0
# 1    10.0
# 2    21.0
# 3     2.0
# 4     0.0

# %%
defense_df.drop(columns=['Player', 'Team_y', 'Position'], inplace=True)
defense_df.rename(columns={'Team_x': 'Team'}, inplace=True)

# %%
defense_df.shape
# Out:
# (32, 38)

# %%
defense_df.isnull().sum()
# Out:
# Team                         0
# GP                           0
# Ttl_Pts_Allowed              0
# Ttl_Offense_Plays_Allowed    0
# Yds_p_Play                   0
# Ttl_Yds                      0
# Rushing_Att                  0
# Rushing_Yds                  0
# Rushing_Yds_p_Att            0
# Rushing_TDs                  0
# Passing_Att                  0
# Passing_Yds_p_Att            0
# Completions                  0
# Yds_p_Completion             0
# Passing_Yds                  0
# Passing_TDs                  0
# RZ_Att                       0
# RZ_TD                        0
# RZ_Percent                   0
# Ttl_Turnovers                0
# Interceptions                0
# Fumbles                      0
# Sacks                        0
# TTL                          0
# Week_1                       0
# Week_2                       0
# Week_3                       0
# Week_4                       0
# Week_5                       4
# Week_6                       4
# Week_7                       4
# Week_8                       4
# Week_9                       4
# Week_10                      4
# Week_11                      4
# Week_12                      0
# Week_13                      2
# Week_14                      0
# dtype: int64

# %%
defense_df
# Out:
#                         Team  GP Ttl_Pts_Allowed Ttl_Offense_Plays_Allowed  \
# 
# 13    0.0     7.0     NaN    17.0     2.0     8.0
# 14   12.0     6.0     NaN     6.0     4.0    12.0
# 15    3.0     NaN     5.0    28.0     4.0     4.0
# 16    6.0     6.0     4.0    15.0    10.0     4.0
# 17    3.0     5.0     5.0     9.0     9.0    12.0
# 18    NaN     3.0     8.0     2.0     7.0     9.0
# 19    2.0    -1.0    17.0    19.0     NaN     2.0
# 20   14.0     1.0     3.0    10.0    -2.0     8.0
# 21    NaN    -4.0     5.0     9.0     3.0     2.0
# 22    3.0    -4.0    12.0     4.0     1.0    10.0
# 23    9.0    10.0     4.0     5.0    13.0     0.0
# 24    4.0     5.0     3.0    16.0     3.0    -1.0
# 25    2.0     1.0     8.0     9.0    -3.0     9.0
# 26    NaN     6.0    20.0     0.0     5.0     2.0
# 27    4.0    11.0     2.0     4.0    14.0     2.0
# 28    0.0     4.0     6.0     0.0     5.0    -1.0
# 29    4.0    16.0    -2.0    -1.0     8.0    -4.0
# 30   -1.0     NaN     8.0     9.0     5.0    -1.0
# 31    0.0     NaN     5.0     1.0     1.0    18.0

# %%
defense_df.fillna('0.0', inplace=True)

# %%
def_int = ['GP', 'Ttl_Pts_Allowed', 'Ttl_Offense_Plays_Allowed', 'Ttl_Yds', 'Rushing_Att', 'Rushing_Yds', 
           'Rushing_TDs', 'Passing_Att', 'Completions', 'Passing_Yds', 'Passing_TDs', 'RZ_Att', 'RZ_TD', 
           'Ttl_Turnovers', 'Interceptions', 'Fumbles', 'Sacks']

def_floats = ['Yds_p_Play', 'TTL', 'Week_1', 'Rushing_Yds_p_Att', 'Passing_Yds_p_Att', 'Yds_p_Completion',
              'Week_2', 'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 'Week_9', 'Week_10', 'Week_11', 
              'Week_12', 'Week_13', 'Week_14']

# %%
remove_comma(defense_df, def_int)

# %%
update_int_dtype(defense_df, def_int)

# %%
adjust_float(defense_df, def_floats)

# %%
update_float_dtype(defense_df, def_floats)

# %%
update_percent(defense_df, 'RZ_Percent')

# %%
rz = ['RZ_Percent']
update_float_dtype(defense_df, rz)

# %%
defense_df.head()
# Out:
#                   Team  GP  Ttl_Pts_Allowed  Ttl_Offense_Plays_Allowed  \
# 0  Pittsburgh Steelers  13              237                        811
# 1       Miami Dolphins  13              245                        821
# 2     Los Angeles Rams  13              246                        815
# 3   New Orleans Saints  13              265                        780
# 4     Baltimore Ravens  13              273                        862
#
#    Yds_p_Play  Ttl_Yds  Rushing_Att  Rushing_Yds  Rushing_Yds_p_Att  \
# 0         4.9     3940          314         1312                4.2
# 1         5.7     4710          341         1563                4.6
# 2         4.6     3716          315         1224                3.9
# 3         5.0     3879          312         1159                3.7
# 4         5.3     4545          329         1477                4.5
#
#    Rushing_TDs  Passing_Att  Passing_Yds_p_Att  Completions  Yds_p_Completion  \
# 0            7          452                5.3          253              11.6
# 1           14          446                6.6          281              12.2
# 2           10          458                5.0          286               9.7
# 3            7          432                5.8          262              11.2
# 4           12          505                5.8          328              10.0
#
#    Passing_Yds  Passing_TDs  RZ_Att  RZ_TD  RZ_Percent  Ttl_Turnovers  \
# 0         2628           19      35     19        54.3             25
# 1         3147           16      38     22        57.9             25
# 2         2492           14      37     22        59.5             21
# 3         2720           22      36     24        66.7             20
# 4         3068           19      38     25        65.8             19
#
#    Interceptions  Fumbles  Sacks   TTL  Week_1  Week_2  Week_3  Week_4  \
# 0             17        8     45 133.0     8.0    13.0     7.0    10.0
# 1             16        9     34 126.0     2.0     2.0    12.0     3.0
# 2             13        8     42 123.0     4.0     7.0     4.0    11.0
# 3             13        7     36  99.0    15.0     4.0    -3.0     4.0
# 4              8       11     28 110.0    15.0    15.0     1.0     6.0
#
#    Week_5  Week_6  Week_7  Week_8  Week_9  Week_10  Week_11  Week_12  Week_13  \
# 0     8.0    18.0     2.0    18.0     7.0     12.0     17.0     14.0      3.0
# 1    12.0    15.0     0.0    17.0     8.0      4.0      5.0     14.0     14.0
# 2    12.0     0.0    15.0     5.0     0.0     13.0      5.0     15.0     11.0
# 3     3.0     0.0     1.0     7.0    16.0     14.0     16.0     14.0      6.0
# 4    26.0     7.0     0.0     4.0    14.0      1.0      3.0      8.0      4.0
#
#    Week_14
# 0      6.0
# 1     10.0
# 2     21.0
# 3      2.0
# 4      0.0

# %% [markdown]
# ## Kicking Stats

# %%
kicking.head()
# Out:
#                 PLAYER POSITION TEAM  GP FGM_A   FG% LNG _1_19 _20_29 _30_39  \
# 0         Younghoe Koo        K  ATL  12    34  97.1  54   0-0    8-8  10-10
# 1        Jason Sanders        K  MIA  13    32  93.8  56   1-1    7-7    4-4
# 2  Rodrigo Blankenship        K  IND  13    30  90.0  44   0-0    7-7  11-12
# 3       Daniel Carlson        K   LV  13    28  92.9  54   0-0  13-13    6-6
# 4           Tyler Bass        K  BUF  13    31  80.6  58   1-1    6-6    6-9
#
#   _40_49 OVER50 XPM_A    XP%  PTS
# 0    8-9    7-7    28   89.3  124
# 1  10-12    8-8    30  100.0  120
# 2   9-10    0-1    37   94.6  116
# 3    3-5    4-4    39   97.4  116
# 4    8-9    4-6    40   95.0  113

# %%
kicking_df = pd.merge(kicking, fantasy_pts, left_on = 'PLAYER', right_on = 'Player')
kicking_df.drop(columns = ['Player', 'Team', 'Position'], inplace = True)
kicking_df
# Out:
#                  PLAYER POSITION TEAM  GP FGM_A    FG% LNG _1_19 _20_29  \
# 0          Younghoe Koo        K  ATL  12    34   97.1  54   0-0    8-8
# 1         Jason Sanders        K  MIA  13    32   93.8  56   1-1    7-7
# 2   Rodrigo Blankenship        K  IND  13    30   90.0  44   0-0    7-7
# 3        Daniel Carlson        K   LV  13    28   92.9  54   0-0  13-13
# 4            Tyler Bass        K  BUF  13    31   80.6  58   1-1    6-6
# 5           Ryan Succop        K   TB  13    26   92.3  50   1-1    7-7
# 6       Harrison Butker        K   KC  13    25   92.0  58   2-2    6-6
# 7             Joey Slye        K  CAR  13    33   78.8  56   0-0  10-11
# 8         Justin Tucker        K  BAL  13    24   91.7  55   0-0    6-6
# 9              Wil Lutz        K   NO  13    25   80.0  53   0-0    5-6
# 10        Greg Zuerlein        K  DAL  13    31   80.6  59   1-1    3-3
# 11          Jason Myers        K  SEA  13    18  100.0  61   0-0    2-2
# 12          Graham Gano        K  NYG  13    27   96.3  55   0-0    4-4
NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 38    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 39    2.0    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 40    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     1.0
# 41    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 42    0.0    NaN    0.0    0.0    0.0     0.0    -2.8     0.0     0.0     0.0

# %%
dash = kicking_df['LNG'][39]
dash
# Out:
# '—'

# %%
kicking_df.fillna('0.0', inplace = True)

# %%
kick_int = ['GP', 'FGM_A', 'LNG', 'XPM_A', 'PTS']

kick_float = ['FG%', 'XP%', 'TTL', 'Week_1', 'Week_2', 'Week_3', 'Week_4', 'Week_5', 'Week_6', 'Week_7', 'Week_8', 
              'Week_9', 'Week_10', 'Week_11', 'Week_12', 'Week_13', 'Week_14']

# %%
replace_dash(kicking_df, kick_int, dash)

# %%
replace_dash(kicking_df, kick_float, dash)

# %%
update_int_dtype(kicking_df, kick_int)

# %%
adjust_float(kicking_df, kick_float)

# %%
update_float_dtype(kicking_df, kick_float)

# %%
kicking_df.head()
# Out:
#                 PLAYER POSITION TEAM  GP  FGM_A  FG%  LNG _1_19 _20_29 _30_39  \
# 0         Younghoe Koo        K  ATL  12     34 97.1   54   0-0    8-8  10-10
# 1        Jason Sanders        K  MIA  13     32 93.8   56   1-1    7-7    4-4
# 2  Rodrigo Blankenship        K  IND  13     30 90.0   44   0-0    7-7  11-12
# 3       Daniel Carlson        K   LV  13     28 92.9   54   0-0  13-13    6-6
# 4           Tyler Bass        K  BUF  13     31 80.6   58   1-1    6-6    6-9
#
#   _40_49 OVER50  XPM_A   XP%  PTS   TTL  Week_1  Week_2  Week_3  Week_4  \
# 0    8-9    7-7     28  89.3  124 146.0     9.0    17.0     8.0     0.0
# 1  10-12    8-8     30 100.0  120 146.0     4.0    11.0     7.0    18.0
# 2   9-10    0-1     37  94.6  116 125.0     8.0    15.0    12.0    14.0
# 3    3-5    4-4     39  97.4  116 127.0    12.0    12.0     8.0    13.0
# 4    8-9    4-6     40  95.0  113 129.0     9.0     7.0     5.0     6.0
#
#    Week_5  Week_6  Week_7  Week_8  Week_9  Week_10  Week_11  Week_12  Week_13  \
# 0    13.0    20.0     2.0    13.0    12.0      0.0     13.0     21.0     12.0
# 1    22.0     6.0     0.0     4.0    14.0     14.0     10.0     12.0     14.0
# 2    11.0     8.0     0.0     3.0     5.0     11.0     15.0      2.0      7.0
# 3    11.0     0.0     9.0    10.0     7.0     15.0      7.0      6.0      8.0
# 4     5.0     6.0    23.0     6.0    15.0     18.0      0.0     11.0     10.0
#
#    Week_14
# 0      6.0
# 1     10.0
# 2     14.0
# 3      9.0
# 4      8.0

# %%
kicking_df.dtypes
# Out:
# PLAYER       object
# POSITION     object
# TEAM         object
# GP            int64
# FGM_A         int64
# FG%         float64
# LNG           int64
# _1_19        object
# _20_29       object
# _30_39       object
# _40_49       object
# OVER50       object
# XPM_A         int64
# XP%         float64
# PTS           int64
# TTL         float64
# Week_1      float64
# Week_2      float64
# Week_3      float64
# Week_4      float64
# Week_5      float64
# Week_6      float64
# Week_7      float64
# Week_8      float64
# Week_9      float64
# Week_10     float64
# Week_11     float64
# Week_12     float64
# Week_13     float64
# Week_14     float64
# dtype: object

# %% [markdown]
# ## Pickle Cleaned DataFrames

# %%
offense.to_pickle('players')
team_names.to_pickle('long_names')
defense_df.to_pickle('defense')
kicking_df.to_pickle('kicking')
